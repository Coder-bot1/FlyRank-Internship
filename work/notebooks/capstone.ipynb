# %% [markdown]
# # Capstone — mirrors your deployed research paper
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Coder-bot1/FlyRank-Internship/blob/main/work/notebooks/capstone.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
import os

print("Current working directory:")
print(os.getcwd())

print("\nFiles/folders here:")
print(os.listdir())
# Out:
# Current working directory:
# /content/FlyRank-Internship
#
# Files/folders here:
# ['scripts', 'requirements.txt', 'data', 'GUIDE.md', 'work', '.github', 'AGENTS.md', 'outputs', 'CLAUDE.md', 'README.md', 'LICENSE', 'submission', '.git', '.gitignore', 'notebooks', 'DATA_USE.md', 'docs', 'SETUP.md', 'skills']

# %%
import os

REPO_PATH = "/content/FlyRank-Internship"

for folder in ["data", "notebooks", "outputs", "submission", "work"]:
    path = os.path.join(REPO_PATH, folder)

    print(f"\n===== {folder}/ =====")

    if os.path.exists(path):
        for item in sorted(os.listdir(path)):
            print(item)
    else:
        print("FOLDER DOES NOT EXIST")
# Out:
# ===== data/ =====
# raw
#
# ===== notebooks/ =====
# 01_first_look_and_discovery.ipynb
# 02_your_first_readable_model.ipynb
# 03_working_with_the_full_release.ipynb
#
# ===== outputs/ =====
# charts
# model_report.md
# refresh_queue_sample.csv
#
# ===== submission/ =====
# README.md
# paper_url.txt
#
# ===== work/ =====
# README.md
# capstone_report_template.md
# notebooks

# %%
import os

RAW_PATH = "/content/FlyRank-Internship/data/raw"

print("Raw data path:")
print(RAW_PATH)

print("\nFiles in data/raw:")
for item in sorted(os.listdir(RAW_PATH)):
    print("-", item)
# Out:
# Raw data path:
# /content/FlyRank-Internship/data/raw
#
# Files in data/raw:
# - content_refresh_anonymized.csv

# %%
import pandas as pd

DATA_PATH = "/content/FlyRank-Internship/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(DATA_PATH)

print("Shape:")
print(df.shape)

print("\nColumns:")
for i, col in enumerate(df.columns, start=1):
    print(f"{i}. {col}")

print("\nFirst 5 rows:")
display(df.head())
# Out:
# Shape:
# (30000, 44)
#
# Columns:
# 1. content_id
# 2. client_id
# 3. search_volume
# 4. competition
# 5. competition_level
# 6. cpc
# 7. content_type
# 8. main_intent
# 9. word_count
# 10. char_count
# 11. provider_used
# 12. model_used
# 13. impressions_90d
# 14. clicks_90d
# 15. pageviews_90d
# 16. sessions_90d
# 17. users_90d
# 18. engaged_sessions_90d
# 19. ai_sessions_90d
# 20. scroll_events_90d
# 21. days_with_impressions
# 22. days_with_sessions
# 23. impressions_last_30d
# 24. clicks_last_30d
# 25. sessions_last_30d
# 26. impressions_prev_30d
# 27. clicks_prev_30d
# 28. sessions_prev_30d
# 29. content_age_days
# 30. age_tier
# 31. age_tier_order
# 32. days_since_last_update
# 33. freshness_tier
# 34. word_count_tier
# 35. char_count_tier
# 36. ctr
# 37. avg_position
# 38. engagement_rate
# 39. scroll_rate
# 40. ai_traffic_pct
# 41. impression_tier
# 42. position_tier
# 43. trend_direction
# 44. trend_pct
#
# First 5 rows:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# 0     20457.0  ...     15000-25000  0.76          10.6             5.88
# 1     15562.0  ...     15000-25000  0.05          20.3             0.00
# 2     23643.0  ...     15000-25000  0.09          36.5             0.00
# 3         NaN  ...             NaN  0.49           6.2             1.28
# 4     17469.0  ...     15000-25000  0.13          44.0             0.00
#
#    scroll_rate  ai_traffic_pct  impression_tier  position_tier  \
# 0         4.55             0.0             good       striking
# 1        10.00             0.0             good       page_3_5
# 2        28.57             0.0             good       page_3_5
# 3         3.45             0.0             good         page_1
# 4        24.29             0.0             good       page_3_5
#
#    trend_direction  trend_pct
# 0             down      -41.4
# 1             down      -57.7
# 2             down      -60.9
# 3           stable      -13.8
# 4             down      -34.7
#
# [5 rows x 44 columns]

# %%
print("===== DUPLICATES =====")
print("Duplicate rows:", df.duplicated().sum())


print("\n===== MISSING VALUES =====")
missing = df.isna().sum()
missing = missing[missing > 0].sort_values(ascending=False)

if len(missing) == 0:
    print("No missing values found.")
else:
    print(missing)


print("\n===== DATA TYPES =====")
print(df.dtypes)


print("\n===== NUMERIC SUMMARY =====")
display(df.describe().T)
# Out:
# ===== DUPLICATES =====
# Duplicate rows: 0
#
# ===== MISSING VALUES =====
# provider_used        21438
# word_count_tier       7699
# char_count            7699
# word_count            7699
# char_count_tier       7699
# model_used            5733
# trend_pct             3388
# competition_level     2610
# search_volume         2468
# competition           2468
# cpc                   2468
# main_intent           2374
# scroll_rate            125
# dtype: int64
#
# ===== DATA TYPES =====
# content_id                 object
# client_id                  object
# search_volume             float64
# competition               float64
# competition_level          object
# cpc                       float64
# content_type               object
# main_intent                object
# word_count                float64
# char_count                float64
# provider_used              object
# model_used                 object
# impressions_90d             int64
# clicks_90d                  int64
# pageviews_90d               int64
# sessions_90d                int64
# users_90d                   int64
# engaged_sessions_90d        int64
# ai_sessions_90d             int64
# scroll_events_90d           int64
# days_with_impressions       int64
# days_with_sessions          int64
# impressions_last_30d        int64
# clicks_last_30d             int64
# sessions_last_30d           int64
# impressions_prev_30d        int64
# clicks_prev_30d             int64
# sessions_prev_30d           int64
# content_age_days            int64
# age_tier                   object
# age_tier_order              int64
# days_since_last_update      int64
# freshness_tier             object
# word_count_tier            object
# char_count_tier            object
# ctr                       float64
# avg_position              float64
# engagement_rate           float64
# scroll_rate               float64
# ai_traffic_pct            float64
# impression_tier            object
# position_tier              object
# trend_direction            object
# trend_pct                 float64
# dtype: object
#
# ===== NUMERIC SUMMARY =====
#                           count          mean           std    min      25%  \
# search_volume           27532.0    158.882391   1518.270825    0.0      0.0
# competition             27532.0      0.146954      0.285241    0.0      0.0
# cpc                     27532.0      0.485342      2.101560    0.0      0.0
# word_count              22301.0   3107.760325   1452.382598    8.0   2413.0
# char_count              22301.0  20665.277835  10115.344042   40.0  15644.0
# impressions_90d         30000.0   5200.366300  16838.019547    1.0     81.0
# clicks_90d              30000.0     16.097333     75.076958    0.0      0.0
# pageviews_90d           30000.0     49.942467    152.101430    0.0      2.0
# sessions_90d            30000.0     37.066633    107.069131    1.0      2.0
# users_90d               30000.0     35.937700    103.748185    1.0      2.0
# engaged_sessions_90d    30000.0      0.991933      4.359576    0.0      0.0
# ai_sessions_90d         30000.0      0.204500      1.363601    0.0      0.0
# scroll_events_90d       30000.0      4.033500     22.335179    0.0      0.0
# days_with_impressions   30000.0     61.454033     32.689245    1.0     31.0
# days_with_sessions      30000.0     13.096333     17.307759    1.0      2.0
# impressions_last_30d    30000.0   1429.058733   5643.852081    0.0     10.0
# clicks_last_30d         30000.0      4.933867     23.929393    0.0      0.0
# sessions_last_30d       30000.0     14.114267     39.036371    0.0      0.0
# impressions_prev_30d    30000.0   1783.078500   6150.429511    0.0     19.0
# clicks_prev_30d         30000.0      5.435100     28.358673    0.0      0.0
# sessions_prev_30d       30000.0     10.283000     42.578003    0.0      1.0
# content_age_days        30000.0    256.167800    132.707930   90.0    132.0
# age_tier_order          30000.0      4.786533      0.790392    3.0      4.0
# days_since_last_update  30000.0     46.098300     42.078709    1.0     20.0
# ctr                     30000.0      0.510733      3.279162    0.0      0.0
# avg_position            30000.0     16.342380     15.216790    0.0      6.2
# engagement_rate         30000.0      2.534520      8.310096    0.0      0.0
# scroll_rate             29875.0     18.212921     29.472768    0.0      0.0
# ai_traffic_pct          30000.0      0.768196      7.429454    0.0      0.0
# trend_pct               26612.0     -4.785969    473.861780 -100.0    -62.6
#
#                              50%       75%        max
# search_volume              10.00     20.00   74000.00
# competition                 0.00      0.13       1.00
# cpc                         0.00      0.00     100.36
# word_count               2877.00   3666.00    9546.00
# char_count              19116.00  24011.00  111158.00
# impressions_90d           731.00   3615.25  517715.00
# clicks_90d                  1.00      7.00    4178.00
# pageviews_90d               8.00     33.00    5998.00
# sessions_90d                7.00     27.00    4345.00
# users_90d                   7.00     27.00    4913.00
# engaged_sessions_90d        0.00      1.00     290.00
# ai_sessions_90d             0.00      0.00      64.00
# scroll_events_90d           1.00      3.00    2605.00
# days_with_impressions      81.00     88.00      88.00
# days_with_sessions          6.00     16.00      90.00
# impressions_last_30d      139.00    768.00  238796.00
# clicks_last_30d             0.00      2.00    1176.00
# sessions_last_30d           3.00     12.00    1081.00
# impressions_prev_30d      210.00   1143.00  218786.00
# clicks_prev_30d             0.00      2.00    1627.00
# sessions_prev_30d           2.00      7.00    4247.00
# content_age_days          236.00    333.00     564.00
# age_tier_order              5.00      5.00       6.00
# days_since_last_update     20.00    104.00     373.00
# ctr                         0.07      0.29     100.00
# avg_position               10.80     22.30     245.00
# engagement_rate             0.00      1.35     100.00
# scroll_rate                 5.00     23.53     300.00
# ai_traffic_pct              0.00      0.00     300.00
# trend_pct                 -33.50      0.00   44900.00

# %%
# Inspect the unique values and basic distributions
# of the categorical/derived fields.

derived_cols = [
    "competition_level",
    "age_tier",
    "freshness_tier",
    "word_count_tier",
    "char_count_tier",
    "impression_tier",
    "position_tier",
    "trend_direction"
]

for col in derived_cols:
    print(f"\n===== {col} =====")
    print("Unique values:", df[col].nunique(dropna=True))
    print(df[col].value_counts(dropna=False).head(15))
# Out:
# ===== competition_level =====
# Unique values: 3
# competition_level
# LOW       22896
# HIGH       2658
# NaN        2610
# MEDIUM     1836
# Name: count, dtype: int64
#
# ===== age_tier =====
# Unique values: 4
# age_tier
# 91-180     11780
# 181-365    11368
# 365+        6360
# 31-90        492
# Name: count, dtype: int64
#
# ===== freshness_tier =====
# Unique values: 4
# freshness_tier
# 0-30      20480
# 91-180     9171
# 31-90       175
# 181+        174
# Name: count, dtype: int64
#
# ===== word_count_tier =====
# Unique values: 4
# word_count_tier
# 2000-3500    11263
# NaN           7699
# 3500+         6285
# 1000-2000     3780
# <1000          973
# Name: count, dtype: int64
#
# ===== char_count_tier =====
# Unique values: 4
# char_count_tier
# 15000-25000    12055
# NaN             7699
# 25000+          5123
# 8000-15000      3805
# <8000           1318
# Name: count, dtype: int64
#
# ===== impression_tier =====
# Unique values: 4
# impression_tier
# low          11248
# moderate     10469
# good          7205
# excellent     1078
# Name: count, dtype: int64
#
# ===== position_tier =====
# Unique values: 5
# position_tier
# page_1      11814
# striking     7304
# page_3_5     7242
# top_3        2321
# deep         1319
# Name: count, dtype: int64
#
# ===== trend_direction =====
# Unique values: 5
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %%
trend_cols = [
    "impressions_last_30d",
    "impressions_prev_30d",
    "clicks_last_30d",
    "clicks_prev_30d",
    "trend_direction",
    "trend_pct"
]

display(
    df[trend_cols]
    .sort_values("trend_pct", ascending=False)
    .head(10)
)

print("\n===== MOST NEGATIVE TRENDS =====")

display(
    df[trend_cols]
    .sort_values("trend_pct", ascending=True)
    .head(10)
)
# Out:
#        impressions_last_30d  impressions_prev_30d  clicks_last_30d  \
# 24695                   450                     1                0
# 15405                212015                   757                8
# 14549                  2364                     9                2
# 3561                    215                     1                0
# 19697                  1546                     9                4
# 24726                  1274                     8                0
# 9097                    150                     1                0
# 27305                   470                     4                5
# 1132                    341                     3                3
# 19525                   227                     2                0
#
#        clicks_prev_30d trend_direction  trend_pct
# 24695                0              up    44900.0
# 15405                2              up    27907.3
# 14549                0              up    26166.7
# 3561                 0              up    21400.0
# 19697                0              up    17077.8
# 24726                0              up    15825.0
# 9097                 0              up    14900.0
# 27305                1              up    11650.0
# 1132                 0              up    11266.7
# 19525                0              up    11250.0
# ===== MOST NEGATIVE TRENDS =====
#        impressions_last_30d  impressions_prev_30d  clicks_last_30d  \
# 19312                     0                   163                0
# 6025                      0                     1                0
# 5980                      0                    23                0
# 19420                     0                     8                0
# 19424                     0                     5                0
# 19427                     0                     2                0
# 19412                     0                     3                0
# 19418                     0                    50                0
# 19367                     0                     2                0
# 1162                      0                     1                0
#
#        clicks_prev_30d trend_direction  trend_pct
# 19312                1            down     -100.0
# 6025                 0            down     -100.0
# 5980                 0            down     -100.0
# 19420                0            down     -100.0
# 19424                0            down     -100.0
# 19427                0            down     -100.0
# 19412                0            down     -100.0
# 19418                0            down     -100.0
# 19367                0            down     -100.0
# 1162                 0            down     -100.0

# %%
# Create a separate working dataframe.
# The original df remains untouched.

score_df = df[
    [
        "content_id",
        "client_id",
        "content_type",
        "main_intent",
        "search_volume",
        "competition",
        "impressions_90d",
        "clicks_90d",
        "avg_position",
        "days_since_last_update",
        "impressions_last_30d",
        "impressions_prev_30d",
        "clicks_last_30d",
        "clicks_prev_30d"
    ]
].copy()

# Robust recent-performance change.
score_df["impression_change"] = (
    score_df["impressions_last_30d"]
    - score_df["impressions_prev_30d"]
)

score_df["click_change"] = (
    score_df["clicks_last_30d"]
    - score_df["clicks_prev_30d"]
)

print("Score dataframe shape:")
print(score_df.shape)

print("\nColumns:")
print(score_df.columns.tolist())

print("\nFirst 5 rows:")
display(score_df.head())
# Out:
# Score dataframe shape:
# (30000, 16)
#
# Columns:
# ['content_id', 'client_id', 'content_type', 'main_intent', 'search_volume', 'competition', 'impressions_90d', 'clicks_90d', 'avg_position', 'days_since_last_update', 'impressions_last_30d', 'impressions_prev_30d', 'clicks_last_30d', 'clicks_prev_30d', 'impression_change', 'click_change']
#
# First 5 rows:
#              content_id          client_id     content_type    main_intent  \
# 0  content_304f48230142  client_f369cb89fc  keyword article  transactional
# 1  content_a1fb4e703a9e  client_4e07408562  keyword article  informational
# 2  content_9aa793d4d895  client_7f2253d7e2  keyword article  informational
# 3  content_331d6c4de07b  client_19581e27de  keyword article     commercial
# 4  content_d99b7a2d90ca  client_3fdba35f04  keyword article  informational
#
#    search_volume  competition  impressions_90d  clicks_90d  avg_position  \
# 0           10.0         0.67             3803          29          10.6
# 1           90.0         0.01            15320           7          20.3
# 2            0.0         0.00            12581          11          36.5
# 3           10.0         0.00            11751          58           6.2
# 4            0.0         0.00            19140          24          44.0
#
#    days_since_last_update  impressions_last_30d  impressions_prev_30d  \
# 0                      20                   578                   987
# 1                      25                  2501                  5915
# 2                      20                  2382                  6089
# 3                      22                  3626                  4206
# 4                      14                  4211                  6452
#
#    clicks_last_30d  clicks_prev_30d  impression_change  click_change
# 0                2               13               -409           -11
# 1                2                1              -3414             1
# 2                1                3              -3707            -2
# 3               22               17               -580             5
# 4               10                2              -2241             8

# %%
scoring_inputs = [
    "search_volume",
    "competition",
    "impressions_90d",
    "clicks_90d",
    "avg_position",
    "days_since_last_update",
    "impressions_last_30d",
    "impressions_prev_30d",
    "clicks_last_30d",
    "clicks_prev_30d"
]

missing_summary = pd.DataFrame({
    "missing_count": score_df[scoring_inputs].isna().sum(),
    "missing_pct": score_df[scoring_inputs].isna().mean() * 100
})

missing_summary = missing_summary.sort_values(
    "missing_count",
    ascending=False
)

display(missing_summary)
# Out:
#                         missing_count  missing_pct
# search_volume                    2468     8.226667
# competition                      2468     8.226667
# impressions_90d                     0     0.000000
# clicks_90d                          0     0.000000
# avg_position                        0     0.000000
# days_since_last_update              0     0.000000
# impressions_last_30d                0     0.000000
# impressions_prev_30d                0     0.000000
# clicks_last_30d                     0     0.000000
# clicks_prev_30d                     0     0.000000

# %%
missing_demand = score_df[
    score_df["search_volume"].isna()
].copy()

print("Rows with missing search volume:", len(missing_demand))

print("\nPerformance summary for missing-search-volume pages:")
display(
    missing_demand[
        [
            "impressions_90d",
            "clicks_90d",
            "avg_position",
            "impressions_last_30d",
            "impressions_prev_30d",
            "clicks_last_30d",
            "clicks_prev_30d"
        ]
    ].describe().T
)

print("\nContent types:")
display(
    missing_demand["content_type"]
    .value_counts(dropna=False)
)

print("\nMain intents:")
display(
    missing_demand["main_intent"]
    .value_counts(dropna=False)
)
# Out:
# Rows with missing search volume: 2468
#
# Performance summary for missing-search-volume pages:
#                        count        mean          std  min  25%  50%    75%  \
# impressions_90d       2468.0  501.106159  2985.248782  1.0  3.0  6.0  76.25
# clicks_90d            2468.0    1.864668    10.547224  0.0  0.0  0.0   1.00
# avg_position          2468.0    7.542626    11.536713  0.0  0.0  4.8   8.30
# impressions_last_30d  2468.0  136.587115   915.420122  0.0  1.0  3.0  10.00
# impressions_prev_30d  2468.0  161.749190  1017.180674  0.0  0.0  1.0  20.00
# clicks_last_30d       2468.0    0.486224     3.224886  0.0  0.0  0.0   0.00
# clicks_prev_30d       2468.0    0.555105     3.136117  0.0  0.0  0.0   0.00
#
#                           max
# impressions_90d       61832.0
# clicks_90d              246.0
# avg_position             90.0
# impressions_last_30d  22984.0
# impressions_prev_30d  23334.0
# clicks_last_30d          90.0
# clicks_prev_30d          59.0
# Content types:
# content_type
# feedly article     2096
# keyword article     372
# Name: count, dtype: int64
# Main intents:
# main_intent
# NaN              2232
# informational     143
# commercial         51
# transactional      42
# Name: count, dtype: int64

# %%
# Create position buckets for analysis

score_df["position_bucket"] = pd.cut(
    score_df["avg_position"],
    bins=[-np.inf, 3, 5, 10, 20, 50, np.inf],
    labels=[
        "1-3",
        "4-5",
        "6-10",
        "11-20",
        "21-50",
        "51+"
    ]
)

position_analysis = (
    score_df
    .groupby("position_bucket", observed=False)
    .agg(
        pages=("content_id", "count"),
        median_ctr=("clicks_90d", lambda x: np.nan)
    )
)

# Calculate CTR from aggregated clicks/impressions
position_analysis = (
    score_df
    .groupby("position_bucket", observed=False)
    .agg(
        pages=("content_id", "count"),
        impressions=("impressions_90d", "sum"),
        clicks=("clicks_90d", "sum")
    )
)

position_analysis["ctr"] = (
    position_analysis["clicks"] /
    position_analysis["impressions"]
)

display(position_analysis)
# Out:
#                  pages  impressions  clicks       ctr
# position_bucket
# 1-3               2346      7562934   37049  0.004899
# 4-5               2782     30702588  140107  0.004563
# 6-10              9060     58658832  171821  0.002929
# 11-20             7273     22819980   79552  0.003486
# 21-50             7225     35038692   53883  0.001538
# 51+               1314      1227963     508  0.000414

# %%
score_df["search_volume_bucket"] = pd.cut(
    score_df["search_volume"],
    bins=[-1, 0, 10, 50, 100, 500, 1000, np.inf],
    labels=[
        "0",
        "1-10",
        "11-50",
        "51-100",
        "101-500",
        "501-1000",
        "1000+"
    ]
)

demand_analysis = (
    score_df
    .groupby("search_volume_bucket", observed=False)
    .agg(
        pages=("content_id", "count"),
        impressions=("impressions_90d", "sum"),
        clicks=("clicks_90d", "sum"),
        median_position=("avg_position", "median")
    )
)

demand_analysis["ctr"] = (
    demand_analysis["clicks"] /
    demand_analysis["impressions"]
)

display(demand_analysis)
# Out:
#                       pages  impressions  clicks  median_position       ctr
# search_volume_bucket
# 0                     11081     65589757  206418            11.50  0.003147
# 1-10                   7311     36448952  124437            11.10  0.003414
# 11-50                  4989     28265621   88356            11.00  0.003126
# 51-100                 1102      7116221   19564            11.60  0.002749
# 101-500                2021     11317545   28163            13.50  0.002488
# 501-1000                468      2403510    5588            17.55  0.002325
# 1000+                   560      3632653    5792            18.70  0.001594

# %%
score_components = [
    "search_volume",
    "impressions_90d",
    "avg_position",
    "impression_change",
    "days_since_last_update"
]

component_summary = score_df[score_components].describe().T

display(component_summary)
# Out:
#                           count         mean           std      min    25%  \
# search_volume           27532.0   158.882391   1518.270825      0.0    0.0
# impressions_90d         30000.0  5200.366300  16838.019547      1.0   81.0
# avg_position            30000.0    16.342380     15.216790      0.0    6.2
# impression_change       30000.0  -354.019767   3117.301837 -97995.0 -261.0
# days_since_last_update  30000.0    46.098300     42.078709      1.0   20.0
#
#                           50%      75%       max
# search_volume            10.0    20.00   74000.0
# impressions_90d         731.0  3615.25  517715.0
# avg_position             10.8    22.30     245.0
# impression_change       -25.0     1.00  211258.0
# days_since_last_update   20.0   104.00     373.0

# %%
zero_position = score_df[
    score_df["avg_position"] == 0
].copy()

print("Rows with avg_position = 0:", len(zero_position))

print("\nSearch volume:")
print(zero_position["search_volume"].describe())

print("\nImpressions:")
print(zero_position["impressions_90d"].describe())

print("\nClicks:")
print(zero_position["clicks_90d"].describe())

print("\nContent types:")
display(
    zero_position["content_type"]
    .value_counts(dropna=False)
)

print("\nMain intents:")
display(
    zero_position["main_intent"]
    .value_counts(dropna=False)
)
# Out:
# Rows with avg_position = 0: 1205
#
# Search volume:
# count      456.000000
# mean       107.741228
# std        913.841756
# min          0.000000
# 25%          0.000000
# 50%         10.000000
# 75%         20.000000
# max      18100.000000
# Name: search_volume, dtype: float64
#
# Impressions:
# count    1205.000000
# mean        1.884647
# std         1.412147
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         3.000000
# max        36.000000
# Name: impressions_90d, dtype: float64
#
# Clicks:
# count    1205.000000
# mean        0.005809
# std         0.076027
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: clicks_90d, dtype: float64
#
# Content types:
# content_type
# feedly article     730
# keyword article    475
# Name: count, dtype: int64
# Main intents:
# main_intent
# NaN              751
# informational    263
# transactional    108
# commercial        78
# navigational       5
# Name: count, dtype: int64

# %%
eligible_mask = (
    score_df["search_volume"].notna()
    & (score_df["avg_position"] > 0)
)

print("Total pages:", len(score_df))
print("Eligible pages:", eligible_mask.sum())
print("Excluded pages:", (~eligible_mask).sum())

print(
    "\nEligible percentage:",
    round(eligible_mask.mean() * 100, 2),
    "%"
)

print("\nReasons for exclusion:")

missing_search = score_df["search_volume"].isna()
zero_position = score_df["avg_position"] <= 0

print("Missing search volume:", missing_search.sum())
print("Position <= 0:", zero_position.sum())

print(
    "Both conditions:",
    (missing_search & zero_position).sum()
)
# Out:
# Total pages: 30000
# Eligible pages: 27076
# Excluded pages: 2924
#
# Eligible percentage: 90.25 %
#
# Reasons for exclusion:
# Missing search volume: 2468
# Position <= 0: 1205
# Both conditions: 749

# %%
eligible_df = score_df.loc[eligible_mask].copy()

print("Eligible dataframe shape:")
print(eligible_df.shape)

print("\nMissing values in eligible scoring inputs:")

eligible_inputs = [
    "search_volume",
    "impressions_90d",
    "clicks_90d",
    "avg_position",
    "days_since_last_update",
    "impressions_last_30d",
    "impressions_prev_30d"
]

display(
    eligible_df[eligible_inputs]
    .isna()
    .sum()
)

print("\nFirst 5 eligible pages:")
display(eligible_df.head())
# Out:
# Eligible dataframe shape:
# (27076, 18)
#
# Missing values in eligible scoring inputs:
# search_volume             0
# impressions_90d           0
# clicks_90d                0
# avg_position              0
# days_since_last_update    0
# impressions_last_30d      0
# impressions_prev_30d      0
# dtype: int64
# First 5 eligible pages:
#              content_id          client_id     content_type    main_intent  \
# 0  content_304f48230142  client_f369cb89fc  keyword article  transactional
# 1  content_a1fb4e703a9e  client_4e07408562  keyword article  informational
# 2  content_9aa793d4d895  client_7f2253d7e2  keyword article  informational
# 3  content_331d6c4de07b  client_19581e27de  keyword article     commercial
# 4  content_d99b7a2d90ca  client_3fdba35f04  keyword article  informational
#
#    search_volume  competition  impressions_90d  clicks_90d  avg_position  \
# 0           10.0         0.67             3803          29          10.6
# 1           90.0         0.01            15320           7          20.3
# 2            0.0         0.00            12581          11          36.5
# 3           10.0         0.00            11751          58           6.2
# 4            0.0         0.00            19140          24          44.0
#
#    days_since_last_update  impressions_last_30d  impressions_prev_30d  \
# 0                      20                   578                   987
# 1                      25                  2501                  5915
# 2                      20                  2382                  6089
# 3                      22                  3626                  4206
# 4                      14                  4211                  6452
#
#    clicks_last_30d  clicks_prev_30d  impression_change  click_change  \
# 0                2               13               -409           -11
# 1                2                1              -3414             1
# 2                1                3              -3707            -2
# 3               22               17               -580             5
# 4               10                2              -2241             8
#
#   position_bucket search_volume_bucket
# 0           11-20                 1-10
# 1           21-50               51-100
# 2           21-50                    0
# 3            6-10                 1-10
# 4           21-50                    0

# %%
# STEP 17: Demand Potential

eligible_df["demand_raw"] = np.log1p(
    eligible_df["search_volume"]
)

eligible_df["demand_score"] = (
    eligible_df["demand_raw"]
    / eligible_df["demand_raw"].max()
) * 100

print("Demand score summary:")
display(
    eligible_df["demand_score"].describe()
)

print("\nExample pages:")
display(
    eligible_df[
        [
            "search_volume",
            "demand_raw",
            "demand_score"
        ]
    ]
    .sort_values("search_volume", ascending=False)
    .head(10)
)
# Out:
# Demand score summary:
# count    27076.000000
# mean        18.621096
# std         18.339359
# min          0.000000
# 25%          0.000000
# 50%         21.387182
# 75%         27.154545
# max        100.000000
# Name: demand_score, dtype: float64
# Example pages:
#        search_volume  demand_raw  demand_score
# 12140        74000.0   11.211834    100.000000
# 28282        60500.0   11.010415     98.203517
# 6972         60500.0   11.010415     98.203517
# 18701        60500.0   11.010415     98.203517
# 17907        60500.0   11.010415     98.203517
# 16005        49500.0   10.809748     96.413738
# 22788        49500.0   10.809748     96.413738
# 13502        49500.0   10.809748     96.413738
# 8055         49500.0   10.809748     96.413738
# 5287         40500.0   10.609082     94.623967

# %%
# STEP 18: Existing Visibility

eligible_df["visibility_raw"] = np.log1p(
    eligible_df["impressions_90d"]
)

eligible_df["visibility_score"] = (
    eligible_df["visibility_raw"]
    / eligible_df["visibility_raw"].max()
) * 100

print("Visibility score summary:")
display(
    eligible_df["visibility_score"].describe()
)

print("\nHighest-visibility pages:")
display(
    eligible_df[
        [
            "impressions_90d",
            "visibility_raw",
            "visibility_score"
        ]
    ]
    .sort_values("impressions_90d", ascending=False)
    .head(10)
)
# Out:
# Visibility score summary:
# count    27076.000000
# mean        49.977506
# std         18.547034
# min          5.268204
# 25%         38.667826
# 50%         52.159785
# 75%         63.465358
# max        100.000000
# Name: visibility_score, dtype: float64
# Highest-visibility pages:
#        impressions_90d  visibility_raw  visibility_score
# 6653            517715       13.157182        100.000000
# 17812           517109       13.156011         99.991098
# 26844           509252       13.140700         99.874731
# 19636           497727       13.117809         99.700748
# 21819           463103       13.045707         99.152743
# 29400           443434       13.002307         98.822882
# 29879           416180       12.938876         98.340780
# 13537           347399       12.758232         96.967816
# 18870           345111       12.751624         96.917594
# 14090           312694       12.652984         96.167883

# %%
position_summary = (
    eligible_df["avg_position"]
    .describe(
        percentiles=[
            0.10,
            0.25,
            0.50,
            0.75,
            0.90,
            0.95
        ]
    )
)

display(position_summary)

print("\nPosition bucket distribution:")

position_counts = (
    eligible_df["position_bucket"]
    .value_counts(sort=False)
    .to_frame("pages")
)

position_counts["percentage"] = (
    position_counts["pages"]
    / len(eligible_df)
    * 100
)

display(position_counts)
# Out:
# count    27076.000000
# mean        17.419715
# std         15.222111
# min          0.100000
# 10%          4.700000
# 25%          6.900000
# 50%         11.900000
# 75%         23.600000
# 90%         37.900000
# 95%         49.000000
# max        245.000000
# Name: avg_position, dtype: float64
# Position bucket distribution:
#                  pages  percentage
# position_bucket
# 1-3                934    3.449549
# 4-5               2457    9.074457
# 6-10              8334   30.780027
# 11-20             7028   25.956567
# 21-50             7063   26.085832
# 51+               1260    4.653568

# %%
# STEP 19B: Ranking Opportunity Score

position_score_map = {
    "1-3": 35,
    "4-5": 85,
    "6-10": 100,
    "11-20": 80,
    "21-50": 50,
    "51+": 20
}

eligible_df["ranking_opportunity_score"] = (
    eligible_df["position_bucket"]
    .map(position_score_map)
    .astype(float)
)

print("Ranking opportunity score summary:")
display(
    eligible_df["ranking_opportunity_score"].describe()
)

print("\nScore by position bucket:")

ranking_check = (
    eligible_df
    .groupby("position_bucket", observed=False)
    .agg(
        pages=("content_id", "count"),
        ranking_score=("ranking_opportunity_score", "first"),
        median_position=("avg_position", "median")
    )
)

display(ranking_check)
# Out:
# Ranking opportunity score summary:
# count    27076.000000
# mean        74.439541
# std         23.804311
# min         20.000000
# 25%         50.000000
# 50%         80.000000
# 75%        100.000000
# max        100.000000
# Name: ranking_opportunity_score, dtype: float64
# Score by position bucket:
#                  pages  ranking_score  median_position
# position_bucket
# 1-3                934           35.0              2.3
# 4-5               2457           85.0              4.3
# 6-10              8334          100.0              7.3
# 11-20             7028           80.0             14.0
# 21-50             7063           50.0             29.0
# 51+               1260           20.0             61.0

# %%
# STEP 20A: Relative impression change

eligible_df["relative_impression_change"] = (
    (
        eligible_df["impressions_last_30d"]
        - eligible_df["impressions_prev_30d"]
    )
    /
    (
        eligible_df["impressions_prev_30d"] + 1
    )
)

print("Relative impression change summary:")

display(
    eligible_df["relative_impression_change"].describe(
        percentiles=[
            0.01,
            0.05,
            0.10,
            0.25,
            0.50,
            0.75,
            0.90,
            0.95,
            0.99
        ]
    )
)

print("\nMost negative changes:")

display(
    eligible_df[
        [
            "impressions_last_30d",
            "impressions_prev_30d",
            "relative_impression_change"
        ]
    ]
    .sort_values(
        "relative_impression_change"
    )
    .head(10)
)

print("\nMost positive changes:")

display(
    eligible_df[
        [
            "impressions_last_30d",
            "impressions_prev_30d",
            "relative_impression_change"
        ]
    ]
    .sort_values(
        "relative_impression_change",
        ascending=False
    )
    .head(10)
)
# Out:
# Relative impression change summary:
# count    27076.000000
# mean        13.012806
# std        323.684971
# min         -0.999492
# 1%          -0.967742
# 5%          -0.870727
# 10%         -0.779088
# 25%         -0.580961
# 50%         -0.291748
# 75%          0.012654
# 90%          0.625294
# 95%          1.368534
# 99%         23.086207
# max      30953.000000
# Name: relative_impression_change, dtype: float64
# Most negative changes:
#        impressions_last_30d  impressions_prev_30d  relative_impression_change
# 2786                      0                  1966                   -0.999492
# 27111                     0                   291                   -0.996575
# 5013                      1                   573                   -0.996516
# 19472                     0                   232                   -0.995708
# 24750                     9                  2234                   -0.995526
# 28455                     0                   204                   -0.995122
# 17693                     0                   202                   -0.995074
# 29435                     0                   171                   -0.994186
# 22896                     0                   165                   -0.993976
# 5715                      0                   164                   -0.993939
# Most positive changes:
#        impressions_last_30d  impressions_prev_30d  relative_impression_change
# 11103                 30953                     0                     30953.0
# 5372                  15617                     0                     15617.0
# 17037                 14362                     0                     14362.0
# 1769                  12852                     0                     12852.0
# 8948                  12327                     0                     12327.0
# 23227                 10849                     0                     10849.0
# 11148                 10749                     0                     10749.0
# 9422                   8946                     0                      8946.0
# 1441                   7533                     0                      7533.0
# 9331                   7183                     0                      7183.0

# %%
# STEP 20B: Robust Performance Decline Score

eligible_df["relative_impression_change_clipped"] = (
    eligible_df["relative_impression_change"]
    .clip(-1, 1)
)

eligible_df["decline_score"] = (
    (1 - eligible_df["relative_impression_change_clipped"])
    / 2
) * 100

print("Decline score summary:")

display(
    eligible_df["decline_score"].describe()
)

print("\nExample decline cases:")

display(
    eligible_df[
        [
            "impressions_last_30d",
            "impressions_prev_30d",
            "relative_impression_change",
            "relative_impression_change_clipped",
            "decline_score"
        ]
    ]
    .sort_values(
        "decline_score",
        ascending=False
    )
    .head(10)
)

print("\nExample growth cases:")

display(
    eligible_df[
        [
            "impressions_last_30d",
            "impressions_prev_30d",
            "relative_impression_change",
            "relative_impression_change_clipped",
            "decline_score"
        ]
    ]
    .sort_values(
        "decline_score"
    )
    .head(10)
)
# Out:
# Decline score summary:
# count    27076.000000
# mean        59.908394
# std         25.823893
# min          0.000000
# 25%         49.367312
# 50%         64.587392
# 75%         79.048038
# max         99.974581
# Name: decline_score, dtype: float64
# Example decline cases:
#        impressions_last_30d  impressions_prev_30d  relative_impression_change  \
# 2786                      0                  1966                   -0.999492
# 27111                     0                   291                   -0.996575
# 5013                      1                   573                   -0.996516
# 19472                     0                   232                   -0.995708
# 24750                     9                  2234                   -0.995526
# 28455                     0                   204                   -0.995122
# 17693                     0                   202                   -0.995074
# 29435                     0                   171                   -0.994186
# 22896                     0                   165                   -0.993976
# 5715                      0                   164                   -0.993939
#
#        relative_impression_change_clipped  decline_score
# 2786                            -0.999492      99.974581
# 27111                           -0.996575      99.828767
# 5013                            -0.996516      99.825784
# 19472                           -0.995708      99.785408
# 24750                           -0.995526      99.776286
# 28455                           -0.995122      99.756098
# 17693                           -0.995074      99.753695
# 29435                           -0.994186      99.709302
# 22896                           -0.993976      99.698795
# 5715                            -0.993939      99.696970
# Example growth cases:
#        impressions_last_30d  impressions_prev_30d  relative_impression_change  \
# 27198                     9                     3                    1.500000
# 19745                   341                   155                    1.192308
# 19791                  6315                  1515                    3.166227
# 7919                    393                   186                    1.106952
# 12437                    37                     3                    8.500000
# 4088                   7149                  3322                    1.151670
# 29048                     1                     0                    1.000000
# 29047                  1088                   165                    5.560241
# 27209                    19                     0                   19.000000
# 25493                    21                     3                    4.500000
#
#        relative_impression_change_clipped  decline_score
# 27198                                 1.0            0.0
# 19745                                 1.0            0.0
# 19791                                 1.0            0.0
# 7919                                  1.0            0.0
# 12437                                 1.0            0.0
# 4088                                  1.0            0.0
# 29048                                 1.0            0.0
# 29047                                 1.0            0.0
# 27209                                 1.0            0.0
# 25493                                 1.0            0.0

# %%
# STEP 21: Freshness Score

freshness_min = eligible_df["days_since_last_update"].min()
freshness_max = eligible_df["days_since_last_update"].max()

eligible_df["freshness_score"] = (
    (
        eligible_df["days_since_last_update"]
        - freshness_min
    )
    /
    (
        freshness_max - freshness_min
    )
) * 100

print("Freshness score summary:")

display(
    eligible_df["freshness_score"].describe()
)

print("\nFreshness score examples:")

display(
    eligible_df[
        [
            "days_since_last_update",
            "freshness_score"
        ]
    ]
    .sort_values(
        "days_since_last_update"
    )
    .head(10)
)

print("\nOldest pages:")

display(
    eligible_df[
        [
            "days_since_last_update",
            "freshness_score"
        ]
    ]
    .sort_values(
        "days_since_last_update",
        ascending=False
    )
    .head(10)
)
# Out:
# Freshness score summary:
# count    27076.000000
# mean        12.504855
# std         11.137230
# min          0.000000
# 25%          5.107527
# 50%          5.645161
# 75%         27.688172
# max        100.000000
# Name: freshness_score, dtype: float64
# Freshness score examples:
#        days_since_last_update  freshness_score
# 14244                       1              0.0
# 2428                        1              0.0
# 14604                       1              0.0
# 14566                       1              0.0
# 24907                       1              0.0
# 25838                       1              0.0
# 25757                       1              0.0
# 25013                       1              0.0
# 25926                       1              0.0
# 25002                       1              0.0
# Oldest pages:
#        days_since_last_update  freshness_score
# 4606                      373       100.000000
# 26242                     373       100.000000
# 29384                     373       100.000000
# 18440                     372        99.731183
# 24216                     372        99.731183
# 15790                     313        83.870968
# 21984                     313        83.870968
# 18841                     313        83.870968
# 7509                      313        83.870968
# 15882                     305        81.720430

# %%
# STEP 22A: Final Refresh Opportunity Score

eligible_df["refresh_opportunity_score"] = (
    0.25 * eligible_df["demand_score"]
    + 0.20 * eligible_df["visibility_score"]
    + 0.25 * eligible_df["ranking_opportunity_score"]
    + 0.20 * eligible_df["decline_score"]
    + 0.10 * eligible_df["freshness_score"]
)

print("Refresh Opportunity Score summary:")

display(
    eligible_df["refresh_opportunity_score"].describe()
)

print("\nTop 20 refresh opportunities:")

top_20 = (
    eligible_df[
        [
            "content_id",
            "client_id",
            "content_type",
            "main_intent",
            "search_volume",
            "impressions_90d",
            "avg_position",
            "days_since_last_update",
            "impressions_last_30d",
            "impressions_prev_30d",
            "demand_score",
            "visibility_score",
            "ranking_opportunity_score",
            "decline_score",
            "freshness_score",
            "refresh_opportunity_score"
        ]
    ]
    .sort_values(
        "refresh_opportunity_score",
        ascending=False
    )
    .head(20)
)

display(top_20)
# Out:
# Refresh Opportunity Score summary:
# count    27076.000000
# mean        46.492825
# std         10.209673
# min          6.564393
# 25%         40.552732
# 50%         47.416202
# 75%         53.651335
# max         78.832992
# Name: refresh_opportunity_score, dtype: float64
# Top 20 refresh opportunities:
#                  content_id          client_id     content_type  \
# 9443   content_8ba781dafa55  client_8527a891e2  keyword article
# 28449  content_e8fc703f7ef0  client_3fdba35f04  keyword article
# 8853   content_d0a2a4e36acc  client_19581e27de  keyword article
# 5118   content_c861e30f2f7a  client_6208ef0f77  keyword article
# 25441  content_548f0bf562a9  client_3fdba35f04  keyword article
# 9851   content_2725d2bcfac1  client_4e07408562  keyword article
# 25772  content_2e0b3dc70916  client_4e07408562  keyword article
# 6653   content_5fe46e04994d  client_4e07408562  keyword article
# 17103  content_e6955a2c59dc  client_4e07408562  keyword article
# 23460  content_2db251d1a841  client_f369cb89fc  keyword article
# 18606  content_7355102c630d  client_3fdba35f04  keyword article
# 24176  content_69e07bfa6f0a  client_4e07408562  keyword article
# 4895   content_d07ea098353c  client_19581e27de  keyword article
# 17812  content_aaef01a50def  client_19581e27de  keyword article
# 10608  content_39e33835267d  client_3fdba35f04  keyword article
# 8931   content_496544bf85aa  client_3fdba35f04  keyword article
# 14190  content_11fcfd65d94c  client_19581e27de  keyword article
# 534    content_3546c7b868f1  client_19581e27de  keyword article
# 19746  content_c3864767af8f  client_19581e27de  keyword article
# 12053  content_f421fb2e10ea  client_19581e27de  keyword article
#
#          main_intent  search_volume  impressions_90d  avg_position  \
# 9443   informational         2900.0            16156           9.0
# 28449  informational         9900.0             2398           9.5
# 8853      commercial         4400.0            20978           7.6
# 5118      commercial        22200.0              215           8.4
# 25441  informational         9900.0            24155           3.2
# 9851   informational         6600.0            27348           9.1
# 25772  informational         9900.0            27948           6.9
# 6653   informational         1900.0           517715           4.2
# 17103  informational         3600.0            37534           7.1
# 23460  informational        14800.0           198671           5.6
# 18606  informational         8100.0            20425           7.5
# 24176  informational          880.0             4618           8.7
# 4895      commercial          390.0            63366           9.4
# 17812  informational         4400.0           517109           5.4
# 10608     commercial         6600.0              670           6.0
# 8931   informational        14800.0            22668           5.0
# 14190     commercial          480.0           149083           6.2
# 534    informational         4400.0             5102           4.6
# 19746     commercial          320.0             8626           9.5
# 12053     commercial         5400.0              152           5.9
#
#        days_since_last_update  impressions_last_30d  impressions_prev_30d  \
# 9443                      104                   350                  2431
# 28449                      14                    80                  2318
# 8853                      104                  3600                  8096
# 5118                      104                    20                   170
# 25441                      41                   908                  6966
# 9851                      104                  5915                  9687
# 25772                     104                  7461                  9055
# 6653                      104                120791                218786
# 17103                     104                 11101                 16387
# 23460                      20                 86434                 84550
# 18606                      26                  3766                  6381
# 24176                     104                   148                  1648
# 4895                      104                 13698                 43925
# 17812                      22                170559                177601
# 10608                     104                    55                   188
# 8931                       40                  1928                  3876
# 14190                     104                 44335                 76811
# 534                       104                   372                  1891
# 19746                     104                   473                  5913
# 12053                     104                     6                    67
#
#        demand_score  visibility_score  ranking_opportunity_score  \
# 9443      71.110675         73.648815                      100.0
# 28449     82.059645         59.152539                      100.0
# 8853      74.827964         75.633803                      100.0
# 5118      89.261870         40.854329                      100.0
# 25441     82.059645         76.705544                       85.0
# 9851      78.443692         77.649113                      100.0
# 25772     82.059645         77.814053                      100.0
# 6653      67.340771        100.000000                       85.0
# 17103     73.038603         80.055357                      100.0
# 23460     85.645668         92.720542                      100.0
# 18606     80.270033         75.430771                      100.0
# 24176     60.481253         64.131768                      100.0
# 4895      53.235783         84.035460                      100.0
# 17812     74.827964         99.991098                      100.0
# 10608     78.443692         49.469325                      100.0
# 8931      85.645668         76.222656                       85.0
# 14190     55.083471         90.538119                      100.0
# 534       74.827964         64.889152                       85.0
# 19746     51.476335         68.879886                      100.0
# 12053     76.654181         38.233399                      100.0
#
#        decline_score  freshness_score  refresh_opportunity_score
# 9443       92.783717        27.688172                  78.832992
# 28449      98.253558         3.494624                  77.345593
# 8853       77.763369        27.688172                  77.155243
# 5118       93.859649        27.688172                  77.027080
# 25441      93.476389        10.752688                  76.876566
# 9851       69.467382        27.688172                  76.803039
# 25772      58.800795        27.688172                  75.606698
# 6653       72.395069        27.688172                  75.333024
# 17103      66.127654        27.688172                  75.265070
# 23460      48.885880         5.107527                  75.243454
# 18606      70.487308         6.720430                  74.923167
# 24176      95.482110        27.688172                  74.811906
# 4895       84.406729        27.688172                  74.766201
# 17812      51.982523         5.645161                  74.666231
# 10608      85.185185        27.688172                  74.310642
# 8931       75.122517        10.483871                  73.978839
# 14190      71.139926        27.688172                  73.875294
# 534        90.142706        27.688172                  73.732180
# 19746      95.992560        27.688172                  73.612390
# 12053      94.852941        27.688172                  73.549630

# %%
# STEP 23A: Create refresh priority tiers

def assign_priority(score):
    if score >= 70:
        return "Critical"
    elif score >= 60:
        return "High"
    elif score >= 45:
        return "Medium"
    else:
        return "Low"


eligible_df["refresh_priority"] = (
    eligible_df["refresh_opportunity_score"]
    .apply(assign_priority)
)

print("Refresh priority distribution:")

priority_summary = (
    eligible_df["refresh_priority"]
    .value_counts()
    .reindex(["Critical", "High", "Medium", "Low"])
)

display(priority_summary)

print("\nPercentage distribution:")

priority_pct = (
    eligible_df["refresh_priority"]
    .value_counts(normalize=True)
    .reindex(["Critical", "High", "Medium", "Low"])
    .mul(100)
    .round(2)
)

display(priority_pct)
# Out:
# Refresh priority distribution:
# refresh_priority
# Critical       86
# High         1856
# Medium      14253
# Low         10881
# Name: count, dtype: int64
# Percentage distribution:
# refresh_priority
# Critical     0.32
# High         6.85
# Medium      52.64
# Low         40.19
# Name: proportion, dtype: float64

# %%
# STEP 24: Build the final refresh queue

refresh_queue = (
    eligible_df
    .sort_values(
        by="refresh_opportunity_score",
        ascending=False
    )
    .reset_index(drop=True)
)

# Add overall priority rank
refresh_queue["refresh_rank"] = (
    refresh_queue.index + 1
)

# Select the columns needed for the operational queue
refresh_queue = refresh_queue[
    [
        "refresh_rank",
        "content_id",
        "client_id",
        "content_type",
        "main_intent",
        "search_volume",
        "competition",
        "impressions_90d",
        "clicks_90d",
        "avg_position",
        "days_since_last_update",
        "impressions_last_30d",
        "impressions_prev_30d",
        "clicks_last_30d",
        "clicks_prev_30d",
        "demand_score",
        "visibility_score",
        "ranking_opportunity_score",
        "decline_score",
        "freshness_score",
        "refresh_opportunity_score",
        "refresh_priority"
    ]
]

print("Refresh queue shape:")
print(refresh_queue.shape)

print("\nTop 20 refresh queue:")

display(
    refresh_queue.head(20)
)

print("\nPriority counts:")

display(
    refresh_queue["refresh_priority"].value_counts()
    .reindex(["Critical", "High", "Medium", "Low"])
)
# Out:
# Refresh queue shape:
# (27076, 22)
#
# Top 20 refresh queue:
#     refresh_rank            content_id          client_id     content_type  \
# 0              1  content_8ba781dafa55  client_8527a891e2  keyword article
# 1              2  content_e8fc703f7ef0  client_3fdba35f04  keyword article
# 2              3  content_d0a2a4e36acc  client_19581e27de  keyword article
# 3              4  content_c861e30f2f7a  client_6208ef0f77  keyword article
# 4              5  content_548f0bf562a9  client_3fdba35f04  keyword article
# 5              6  content_2725d2bcfac1  client_4e07408562  keyword article
# 6              7  content_2e0b3dc70916  client_4e07408562  keyword article
# 7              8  content_5fe46e04994d  client_4e07408562  keyword article
# 8              9  content_e6955a2c59dc  client_4e07408562  keyword article
# 9             10  content_2db251d1a841  client_f369cb89fc  keyword article
# 10            11  content_7355102c630d  client_3fdba35f04  keyword article
# 11            12  content_69e07bfa6f0a  client_4e07408562  keyword article
# 12            13  content_d07ea098353c  client_19581e27de  keyword article
# 13            14  content_aaef01a50def  client_19581e27de  keyword article
# 14            15  content_39e33835267d  client_3fdba35f04  keyword article
# 15            16  content_496544bf85aa  client_3fdba35f04  keyword article
# 16            17  content_11fcfd65d94c  client_19581e27de  keyword article
# 17            18  content_3546c7b868f1  client_19581e27de  keyword article
# 18            19  content_c3864767af8f  client_19581e27de  keyword article
# 19            20  content_f421fb2e10ea  client_19581e27de  keyword article
#
#       main_intent  search_volume  competition  impressions_90d  clicks_90d  \
# 0   informational         2900.0         0.02            16156           0
# 1   informational         9900.0         0.04             2398           0
# 2      commercial         4400.0         0.26            20978          13
# 3      commercial        22200.0         0.84              215           4
# 4   informational         9900.0         0.04            24155          13
# 5   informational         6600.0         0.00            27348           6
# 6   informational         9900.0         0.00            27948          11
# 7   informational         1900.0         0.00           517715         741
# 8   informational         3600.0         0.00            37534          26
# 9   informational        14800.0         0.00           198671         361
# 10  informational         8100.0         0.88            20425          28
# 11  informational          880.0         0.12             4618           2
# 12     commercial          390.0         0.16            63366          21
# 13  informational         4400.0         0.05           517109        1270
# 14     commercial         6600.0         0.98              670           1
# 15  informational        14800.0         0.05            22668           8
# 16     commercial          480.0         0.27           149083         227
# 17  informational         4400.0         0.02             5102           8
# 18     commercial          320.0         0.96             8626          15
# 19     commercial         5400.0         0.11              152           0
#
#     avg_position  ...  impressions_prev_30d  clicks_last_30d  clicks_prev_30d  \
# 0            9.0  ...                  2431                0                0
# 1            9.5  ...                  2318                0                0
# 2            7.6  ...                  8096                1                2
# 3            8.4  ...                   170                0                4
# 4            3.2  ...                  6966                1                3
# 5            9.1  ...                  9687                0                3
# 6            6.9  ...                  9055                4                1
# 7            4.2  ...                218786              220              250
# 8            7.1  ...                 16387                5               17
# 9            5.6  ...                 84550              181              114
# 10           7.5  ...                  6381                4                6
# 11           8.7  ...                  1648                0                1
# 12           9.4  ...                 43925                9                7
# 13           5.4  ...                177601              435              461
# 14           6.0  ...                   188                0                0
# 15           5.0  ...                  3876                2                1
# 16           6.2  ...                 76811               52              106
# 17           4.6  ...                  1891                1                1
# 18           9.5  ...                  5913                0                8
# 19           5.9  ...                    67                0                0
#
#     demand_score  visibility_score  ranking_opportunity_score  decline_score  \
# 0      71.110675         73.648815                      100.0      92.783717
# 1      82.059645         59.152539                      100.0      98.253558
# 2      74.827964         75.633803                      100.0      77.763369
# 3      89.261870         40.854329                      100.0      93.859649
# 4      82.059645         76.705544                       85.0      93.476389
# 5      78.443692         77.649113                      100.0      69.467382
# 6      82.059645         77.814053                      100.0      58.800795
# 7      67.340771        100.000000                       85.0      72.395069
# 8      73.038603         80.055357                      100.0      66.127654
# 9      85.645668         92.720542                      100.0      48.885880
# 10     80.270033         75.430771                      100.0      70.487308
# 11     60.481253         64.131768                      100.0      95.482110
# 12     53.235783         84.035460                      100.0      84.406729
# 13     74.827964         99.991098                      100.0      51.982523
# 14     78.443692         49.469325                      100.0      85.185185
# 15     85.645668         76.222656                       85.0      75.122517
# 16     55.083471         90.538119                      100.0      71.139926
# 17     74.827964         64.889152                       85.0      90.142706
# 18     51.476335         68.879886                      100.0      95.992560
# 19     76.654181         38.233399                      100.0      94.852941
#
#     freshness_score  refresh_opportunity_score  refresh_priority
# 0         27.688172                  78.832992          Critical
# 1          3.494624                  77.345593          Critical
# 2         27.688172                  77.155243          Critical
# 3         27.688172                  77.027080          Critical
# 4         10.752688                  76.876566          Critical
# 5         27.688172                  76.803039          Critical
# 6         27.688172                  75.606698          Critical
# 7         27.688172                  75.333024          Critical
# 8         27.688172                  75.265070          Critical
# 9          5.107527                  75.243454          Critical
# 10         6.720430                  74.923167          Critical
# 11        27.688172                  74.811906          Critical
# 12        27.688172                  74.766201          Critical
# 13         5.645161                  74.666231          Critical
# 14        27.688172                  74.310642          Critical
# 15        10.483871                  73.978839          Critical
# 16        27.688172                  73.875294          Critical
# 17        27.688172                  73.732180          Critical
# 18        27.688172                  73.612390          Critical
# 19        27.688172                  73.549630          Critical
#
# [20 rows x 22 columns]
# Priority counts:
# refresh_priority
# Critical       86
# High         1856
# Medium      14253
# Low         10881
# Name: count, dtype: int64

# %%
# STEP 25: Sanity check the Critical pages

critical_pages = refresh_queue[
    refresh_queue["refresh_priority"] == "Critical"
].copy()

print("===== CRITICAL PAGE SANITY CHECK =====")

print("\nNumber of Critical pages:")
print(len(critical_pages))

print("\nContent type distribution:")
display(
    critical_pages["content_type"]
    .value_counts()
)

print("\nMain intent distribution:")
display(
    critical_pages["main_intent"]
    .value_counts(dropna=False)
)

print("\nSearch volume summary:")
display(
    critical_pages["search_volume"].describe()
)

print("\nAverage position summary:")
display(
    critical_pages["avg_position"].describe()
)

print("\nDays since last update:")
display(
    critical_pages["days_since_last_update"].describe()
)

print("\nScore component averages:")

display(
    critical_pages[
        [
            "demand_score",
            "visibility_score",
            "ranking_opportunity_score",
            "decline_score",
            "freshness_score",
            "refresh_opportunity_score"
        ]
    ].mean()
)

print("\nTop 10 Critical pages:")

display(
    critical_pages.head(10)
)
# Out:
# ===== CRITICAL PAGE SANITY CHECK =====
#
# Number of Critical pages:
# 86
#
# Content type distribution:
# content_type
# keyword article    86
# Name: count, dtype: int64
# Main intent distribution:
# main_intent
# informational    55
# commercial       23
# transactional     8
# Name: count, dtype: int64
# Search volume summary:
# count       86.000000
# mean      4697.674419
# std       7716.444423
# min         70.000000
# 25%        507.500000
# 50%       1600.000000
# 75%       4400.000000
# max      49500.000000
# Name: search_volume, dtype: float64
# Average position summary:
# count    86.000000
# mean      7.350000
# std       2.193506
# min       3.100000
# 25%       6.000000
# 50%       7.050000
# 75%       8.550000
# max      16.100000
# Name: avg_position, dtype: float64
# Days since last update:
# count     86.000000
# mean      62.418605
# std       50.446119
# min        7.000000
# 25%       20.000000
# 50%       37.500000
# 75%      104.000000
# max      313.000000
# Name: days_since_last_update, dtype: float64
# Score component averages:
# demand_score                 65.794095
# visibility_score             69.675968
# ranking_opportunity_score    97.209302
# decline_score                79.963962
# freshness_score              16.510378
# refresh_opportunity_score    72.329873
# dtype: float64
# Top 10 Critical pages:
#    refresh_rank            content_id          client_id     content_type  \
# 0             1  content_8ba781dafa55  client_8527a891e2  keyword article
# 1             2  content_e8fc703f7ef0  client_3fdba35f04  keyword article
# 2             3  content_d0a2a4e36acc  client_19581e27de  keyword article
# 3             4  content_c861e30f2f7a  client_6208ef0f77  keyword article
# 4             5  content_548f0bf562a9  client_3fdba35f04  keyword article
# 5             6  content_2725d2bcfac1  client_4e07408562  keyword article
# 6             7  content_2e0b3dc70916  client_4e07408562  keyword article
# 7             8  content_5fe46e04994d  client_4e07408562  keyword article
# 8             9  content_e6955a2c59dc  client_4e07408562  keyword article
# 9            10  content_2db251d1a841  client_f369cb89fc  keyword article
#
#      main_intent  search_volume  competition  impressions_90d  clicks_90d  \
# 0  informational         2900.0         0.02            16156           0
# 1  informational         9900.0         0.04             2398           0
# 2     commercial         4400.0         0.26            20978          13
# 3     commercial        22200.0         0.84              215           4
# 4  informational         9900.0         0.04            24155          13
# 5  informational         6600.0         0.00            27348           6
# 6  informational         9900.0         0.00            27948          11
# 7  informational         1900.0         0.00           517715         741
# 8  informational         3600.0         0.00            37534          26
# 9  informational        14800.0         0.00           198671         361
#
#    avg_position  ...  impressions_prev_30d  clicks_last_30d  clicks_prev_30d  \
# 0           9.0  ...                  2431                0                0
# 1           9.5  ...                  2318                0                0
# 2           7.6  ...                  8096                1                2
# 3           8.4  ...                   170                0                4
# 4           3.2  ...                  6966                1                3
# 5           9.1  ...                  9687                0                3
# 6           6.9  ...                  9055                4                1
# 7           4.2  ...                218786              220              250
# 8           7.1  ...                 16387                5               17
# 9           5.6  ...                 84550              181              114
#
#    demand_score  visibility_score  ranking_opportunity_score  decline_score  \
# 0     71.110675         73.648815                      100.0      92.783717
# 1     82.059645         59.152539                      100.0      98.253558
# 2     74.827964         75.633803                      100.0      77.763369
# 3     89.261870         40.854329                      100.0      93.859649
# 4     82.059645         76.705544                       85.0      93.476389
# 5     78.443692         77.649113                      100.0      69.467382
# 6     82.059645         77.814053                      100.0      58.800795
# 7     67.340771        100.000000                       85.0      72.395069
# 8     73.038603         80.055357                      100.0      66.127654
# 9     85.645668         92.720542                      100.0      48.885880
#
#    freshness_score  refresh_opportunity_score  refresh_priority
# 0        27.688172                  78.832992          Critical
# 1         3.494624                  77.345593          Critical
# 2        27.688172                  77.155243          Critical
# 3        27.688172                  77.027080          Critical
# 4        10.752688                  76.876566          Critical
# 5        27.688172                  76.803039          Critical
# 6        27.688172                  75.606698          Critical
# 7        27.688172                  75.333024          Critical
# 8        27.688172                  75.265070          Critical
# 9         5.107527                  75.243454          Critical
#
# [10 rows x 22 columns]

# %%
# ============================================================
# FINAL SCORE VALIDATION
# ============================================================

score_cols = [
    "demand_score",
    "visibility_score",
    "ranking_opportunity_score",
    "decline_score",
    "freshness_score",
    "refresh_opportunity_score"
]

print("===== SCORE RANGE VALIDATION =====")

for col in score_cols:
    print(f"\n{col}")
    print("Min:", eligible_df[col].min())
    print("Max:", eligible_df[col].max())
    print("Missing:", eligible_df[col].isna().sum())
# Out:
# ===== SCORE RANGE VALIDATION =====
#
# demand_score
# Min: 0.0
# Max: 100.0
# Missing: 0
#
# visibility_score
# Min: 5.268203896945729
# Max: 100.0
# Missing: 0
#
# ranking_opportunity_score
# Min: 20.0
# Max: 100.0
# Missing: 0
#
# decline_score
# Min: 0.0
# Max: 99.97458057956278
# Missing: 0
#
# freshness_score
# Min: 0.0
# Max: 100.0
# Missing: 0
#
# refresh_opportunity_score
# Min: 6.564393467561189
# Max: 78.83299237905797
# Missing: 0

# %%
print("\n===== INVALID SCORE CHECK =====")

for col in score_cols:
    invalid = ((eligible_df[col] < 0) | (eligible_df[col] > 100)).sum()
    print(f"{col}: {invalid} invalid values")
# Out:
# ===== INVALID SCORE CHECK =====
# demand_score: 0 invalid values
# visibility_score: 0 invalid values
# ranking_opportunity_score: 0 invalid values
# decline_score: 0 invalid values
# freshness_score: 0 invalid values
# refresh_opportunity_score: 0 invalid values

# %%
# ============================================================
# STEP 2 — SCORE CORRELATION ANALYSIS
# ============================================================

score_cols = [
    "demand_score",
    "visibility_score",
    "ranking_opportunity_score",
    "decline_score",
    "freshness_score",
    "refresh_opportunity_score"
]

correlation_matrix = eligible_df[score_cols].corr().round(3)

print("===== SCORE CORRELATION MATRIX =====")
display(correlation_matrix)
# Out:
# ===== SCORE CORRELATION MATRIX =====
#                            demand_score  visibility_score  \
# demand_score                      1.000            -0.022
# visibility_score                 -0.022             1.000
# ranking_opportunity_score        -0.058             0.105
# decline_score                    -0.092             0.092
# freshness_score                  -0.076             0.182
# refresh_opportunity_score         0.353             0.481
#
#                            ranking_opportunity_score  decline_score  \
# demand_score                                  -0.058         -0.092
# visibility_score                               0.105          0.092
# ranking_opportunity_score                      1.000          0.091
# decline_score                                  0.091          1.000
# freshness_score                               -0.064          0.065
# refresh_opportunity_score                      0.634          0.558
#
#                            freshness_score  refresh_opportunity_score
# demand_score                        -0.076                      0.353
# visibility_score                     0.182                      0.481
# ranking_opportunity_score           -0.064                      0.634
# decline_score                        0.065                      0.558
# freshness_score                      1.000                      0.136
# refresh_opportunity_score            0.136                      1.000

# %%
print("===== UNIQUE VALUES =====")

for col in score_cols:
    print(
        f"{col}: "
        f"{eligible_df[col].nunique()} unique values"
    )
# Out:
# ===== UNIQUE VALUES =====
# demand_score: 41 unique values
# visibility_score: 9385 unique values
# ranking_opportunity_score: 6 unique values
# decline_score: 17411 unique values
# freshness_score: 51 unique values
# refresh_opportunity_score: 26341 unique values

# %%
# ============================================================
# STEP 3 — PRIORITY GROUP VALIDATION
# ============================================================

priority_order = ["Critical", "High", "Medium", "Low"]

priority_summary = (
    refresh_queue
    .groupby("refresh_priority", observed=True)
    .agg(
        pages=("content_id", "count"),
        avg_refresh_score=("refresh_opportunity_score", "mean"),
        median_refresh_score=("refresh_opportunity_score", "median"),
        avg_demand=("demand_score", "mean"),
        avg_visibility=("visibility_score", "mean"),
        avg_ranking_opportunity=("ranking_opportunity_score", "mean"),
        avg_decline=("decline_score", "mean"),
        avg_freshness=("freshness_score", "mean"),
        avg_position=("avg_position", "mean")
    )
    .reindex(priority_order)
    .round(2)
)

print("===== PRIORITY GROUP VALIDATION =====")
display(priority_summary)
# Out:
# ===== PRIORITY GROUP VALIDATION =====
#                   pages  avg_refresh_score  median_refresh_score  avg_demand  \
# refresh_priority
# Critical             86              72.33                 71.70       65.79
# High               1856              62.96                 62.36       40.45
# Medium            14253              51.72                 51.46       19.71
# Low               10881              36.63                 38.76       13.10
#
#                   avg_visibility  avg_ranking_opportunity  avg_decline  \
# refresh_priority
# Critical                   69.68                    97.21        79.96
# High                       63.07                    95.26        74.81
# Medium                     54.69                    83.42        68.40
# Low                        41.42                    58.95        46.09
#
#                   avg_freshness  avg_position
# refresh_priority
# Critical                  16.51          7.35
# High                      14.60          7.94
# Medium                    13.22         12.89
# Low                       11.18         25.06

# %%
print("===== PRIORITY COUNTS =====")

priority_counts = (
    refresh_queue["refresh_priority"]
    .value_counts()
    .reindex(priority_order)
)

display(priority_counts)
# Out:
# ===== PRIORITY COUNTS =====
# refresh_priority
# Critical       86
# High         1856
# Medium      14253
# Low         10881
# Name: count, dtype: int64

# %%
print("===== PRIORITY PERCENTAGES =====")

priority_percentages = (
    refresh_queue["refresh_priority"]
    .value_counts(normalize=True)
    .reindex(priority_order)
    .mul(100)
    .round(2)
)

display(priority_percentages)
# Out:
# ===== PRIORITY PERCENTAGES =====
# refresh_priority
# Critical     0.32
# High         6.85
# Medium      52.64
# Low         40.19
# Name: proportion, dtype: float64

# %%
# ============================================================
# STEP 4 — ACTIONABLE REFRESH RECOMMENDATIONS
# ============================================================

def refresh_reason(row):
    reasons = []

    if row["ranking_opportunity_score"] >= 85:
        reasons.append("strong ranking opportunity")

    if row["decline_score"] >= 75:
        reasons.append("significant performance decline")

    if row["freshness_score"] >= 50:
        reasons.append("content is stale")

    if row["demand_score"] >= 70:
        reasons.append("high search demand")

    if row["visibility_score"] >= 70:
        reasons.append("strong existing visibility")

    if not reasons:
        reasons.append("moderate refresh opportunity")

    return "; ".join(reasons)


refresh_queue["refresh_reason"] = refresh_queue.apply(
    refresh_reason,
    axis=1
)

print("===== REFRESH REASONS CREATED =====")
display(
    refresh_queue[
        [
            "content_id",
            "refresh_opportunity_score",
            "refresh_priority",
            "refresh_reason"
        ]
    ].head(10)
)
# Out:
# ===== REFRESH REASONS CREATED =====
#              content_id  refresh_opportunity_score refresh_priority  \
# 0  content_8ba781dafa55                  78.832992         Critical
# 1  content_e8fc703f7ef0                  77.345593         Critical
# 2  content_d0a2a4e36acc                  77.155243         Critical
# 3  content_c861e30f2f7a                  77.027080         Critical
# 4  content_548f0bf562a9                  76.876566         Critical
# 5  content_2725d2bcfac1                  76.803039         Critical
# 6  content_2e0b3dc70916                  75.606698         Critical
# 7  content_5fe46e04994d                  75.333024         Critical
# 8  content_e6955a2c59dc                  75.265070         Critical
# 9  content_2db251d1a841                  75.243454         Critical
#
#                                       refresh_reason
# 0  strong ranking opportunity; significant perfor...
# 1  strong ranking opportunity; significant perfor...
# 2  strong ranking opportunity; significant perfor...
# 3  strong ranking opportunity; significant perfor...
# 4  strong ranking opportunity; significant perfor...
# 5  strong ranking opportunity; high search demand...
# 6  strong ranking opportunity; high search demand...
# 7  strong ranking opportunity; strong existing vi...
# 8  strong ranking opportunity; high search demand...
# 9  strong ranking opportunity; high search demand...

# %%
def recommended_action(row):

    if row["refresh_priority"] == "Critical":
        return "Refresh immediately"

    elif row["refresh_priority"] == "High":
        return "Refresh next"

    elif row["refresh_priority"] == "Medium":
        return "Schedule refresh / monitor"

    else:
        return "Monitor"


refresh_queue["recommended_action"] = refresh_queue.apply(
    recommended_action,
    axis=1
)

print("===== RECOMMENDED ACTIONS CREATED =====")

display(
    refresh_queue[
        [
            "content_id",
            "refresh_priority",
            "refresh_opportunity_score",
            "refresh_reason",
            "recommended_action"
        ]
    ].head(20)
)
# Out:
# ===== RECOMMENDED ACTIONS CREATED =====
#               content_id refresh_priority  refresh_opportunity_score  \
# 0   content_8ba781dafa55         Critical                  78.832992
# 1   content_e8fc703f7ef0         Critical                  77.345593
# 2   content_d0a2a4e36acc         Critical                  77.155243
# 3   content_c861e30f2f7a         Critical                  77.027080
# 4   content_548f0bf562a9         Critical                  76.876566
# 5   content_2725d2bcfac1         Critical                  76.803039
# 6   content_2e0b3dc70916         Critical                  75.606698
# 7   content_5fe46e04994d         Critical                  75.333024
# 8   content_e6955a2c59dc         Critical                  75.265070
# 9   content_2db251d1a841         Critical                  75.243454
# 10  content_7355102c630d         Critical                  74.923167
# 11  content_69e07bfa6f0a         Critical                  74.811906
# 12  content_d07ea098353c         Critical                  74.766201
# 13  content_aaef01a50def         Critical                  74.666231
# 14  content_39e33835267d         Critical                  74.310642
# 15  content_496544bf85aa         Critical                  73.978839
# 16  content_11fcfd65d94c         Critical                  73.875294
# 17  content_3546c7b868f1         Critical                  73.732180
# 18  content_c3864767af8f         Critical                  73.612390
# 19  content_f421fb2e10ea         Critical                  73.549630
#
#                                        refresh_reason   recommended_action
# 0   strong ranking opportunity; significant perfor...  Refresh immediately
# 1   strong ranking opportunity; significant perfor...  Refresh immediately
# 2   strong ranking opportunity; significant perfor...  Refresh immediately
# 3   strong ranking opportunity; significant perfor...  Refresh immediately
# 4   strong ranking opportunity; significant perfor...  Refresh immediately
# 5   strong ranking opportunity; high search demand...  Refresh immediately
# 6   strong ranking opportunity; high search demand...  Refresh immediately
# 7   strong ranking opportunity; strong existing vi...  Refresh immediately
# 8   strong ranking opportunity; high search demand...  Refresh immediately
# 9   strong ranking opportunity; high search demand...  Refresh immediately
# 10  strong ranking opportunity; high search demand...  Refresh immediately
# 11  strong ranking opportunity; significant perfor...  Refresh immediately
# 12  strong ranking opportunity; significant perfor...  Refresh immediately
# 13  strong ranking opportunity; high search demand...  Refresh immediately
# 14  strong ranking opportunity; significant perfor...  Refresh immediately
# 15  strong ranking opportunity; significant perfor...  Refresh immediately
# 16  strong ranking opportunity; strong existing vi...  Refresh immediately
# 17  strong ranking opportunity; significant perfor...  Refresh immediately
# 18  strong ranking opportunity; significant perfor...  Refresh immediately
# 19  strong ranking opportunity; significant perfor...  Refresh immediately

# %%
print("===== CRITICAL PAGE RECOMMENDATIONS =====")

critical_pages = refresh_queue[
    refresh_queue["refresh_priority"] == "Critical"
]

display(
    critical_pages[
        [
            "refresh_rank",
            "content_id",
            "search_volume",
            "avg_position",
            "demand_score",
            "visibility_score",
            "ranking_opportunity_score",
            "decline_score",
            "freshness_score",
            "refresh_opportunity_score",
            "refresh_priority",
            "refresh_reason",
            "recommended_action"
        ]
    ].head(20)
)
# Out:
# ===== CRITICAL PAGE RECOMMENDATIONS =====
#     refresh_rank            content_id  search_volume  avg_position  \
# 0              1  content_8ba781dafa55         2900.0           9.0
# 1              2  content_e8fc703f7ef0         9900.0           9.5
# 2              3  content_d0a2a4e36acc         4400.0           7.6
# 3              4  content_c861e30f2f7a        22200.0           8.4
# 4              5  content_548f0bf562a9         9900.0           3.2
# 5              6  content_2725d2bcfac1         6600.0           9.1
# 6              7  content_2e0b3dc70916         9900.0           6.9
# 7              8  content_5fe46e04994d         1900.0           4.2
# 8              9  content_e6955a2c59dc         3600.0           7.1
# 9             10  content_2db251d1a841        14800.0           5.6
# 10            11  content_7355102c630d         8100.0           7.5
# 11            12  content_69e07bfa6f0a          880.0           8.7
# 12            13  content_d07ea098353c          390.0           9.4
# 13            14  content_aaef01a50def         4400.0           5.4
# 14            15  content_39e33835267d         6600.0           6.0
# 15            16  content_496544bf85aa        14800.0           5.0
# 16            17  content_11fcfd65d94c          480.0           6.2
# 17            18  content_3546c7b868f1         4400.0           4.6
# 18            19  content_c3864767af8f          320.0           9.5
# 19            20  content_f421fb2e10ea         5400.0           5.9
#
#     demand_score  visibility_score  ranking_opportunity_score  decline_score  \
# 0      71.110675         73.648815                      100.0      92.783717
# 1      82.059645         59.152539                      100.0      98.253558
# 2      74.827964         75.633803                      100.0      77.763369
# 3      89.261870         40.854329                      100.0      93.859649
# 4      82.059645         76.705544                       85.0      93.476389
# 5      78.443692         77.649113                      100.0      69.467382
# 6      82.059645         77.814053                      100.0      58.800795
# 7      67.340771        100.000000                       85.0      72.395069
# 8      73.038603         80.055357                      100.0      66.127654
# 9      85.645668         92.720542                      100.0      48.885880
# 10     80.270033         75.430771                      100.0      70.487308
# 11     60.481253         64.131768                      100.0      95.482110
# 12     53.235783         84.035460                      100.0      84.406729
# 13     74.827964         99.991098                      100.0      51.982523
# 14     78.443692         49.469325                      100.0      85.185185
# 15     85.645668         76.222656                       85.0      75.122517
# 16     55.083471         90.538119                      100.0      71.139926
# 17     74.827964         64.889152                       85.0      90.142706
# 18     51.476335         68.879886                      100.0      95.992560
# 19     76.654181         38.233399                      100.0      94.852941
#
#     freshness_score  refresh_opportunity_score refresh_priority  \
# 0         27.688172                  78.832992         Critical
# 1          3.494624                  77.345593         Critical
# 2         27.688172                  77.155243         Critical
# 3         27.688172                  77.027080         Critical
# 4         10.752688                  76.876566         Critical
# 5         27.688172                  76.803039         Critical
# 6         27.688172                  75.606698         Critical
# 7         27.688172                  75.333024         Critical
# 8         27.688172                  75.265070         Critical
# 9          5.107527                  75.243454         Critical
# 10         6.720430                  74.923167         Critical
# 11        27.688172                  74.811906         Critical
# 12        27.688172                  74.766201         Critical
# 13         5.645161                  74.666231         Critical
# 14        27.688172                  74.310642         Critical
# 15        10.483871                  73.978839         Critical
# 16        27.688172                  73.875294         Critical
# 17        27.688172                  73.732180         Critical
# 18        27.688172                  73.612390         Critical
# 19        27.688172                  73.549630         Critical
#
#                                        refresh_reason   recommended_action
# 0   strong ranking opportunity; significant perfor...  Refresh immediately
# 1   strong ranking opportunity; significant perfor...  Refresh immediately
# 2   strong ranking opportunity; significant perfor...  Refresh immediately
# 3   strong ranking opportunity; significant perfor...  Refresh immediately
# 4   strong ranking opportunity; significant perfor...  Refresh immediately
# 5   strong ranking opportunity; high search demand...  Refresh immediately
# 6   strong ranking opportunity; high search demand...  Refresh immediately
# 7   strong ranking opportunity; strong existing vi...  Refresh immediately
# 8   strong ranking opportunity; high search demand...  Refresh immediately
# 9   strong ranking opportunity; high search demand...  Refresh immediately
# 10  strong ranking opportunity; high search demand...  Refresh immediately
# 11  strong ranking opportunity; significant perfor...  Refresh immediately
# 12  strong ranking opportunity; significant perfor...  Refresh immediately
# 13  strong ranking opportunity; high search demand...  Refresh immediately
# 14  strong ranking opportunity; significant perfor...  Refresh immediately
# 15  strong ranking opportunity; significant perfor...  Refresh immediately
# 16  strong ranking opportunity; strong existing vi...  Refresh immediately
# 17  strong ranking opportunity; significant perfor...  Refresh immediately
# 18  strong ranking opportunity; significant perfor...  Refresh immediately
# 19  strong ranking opportunity; significant perfor...  Refresh immediately

# %%
# ==========================================
# FINAL REFRESH PRIORITY ANALYSIS
# ==========================================

print("===== REFRESH PRIORITY ANALYSIS =====\n")

# 1. Priority distribution
priority_summary = (
    refresh_queue
    .groupby("refresh_priority")
    .agg(
        pages=("content_id", "count"),
        avg_score=("refresh_opportunity_score", "mean"),
        median_score=("refresh_opportunity_score", "median"),
        avg_demand=("demand_score", "mean"),
        avg_visibility=("visibility_score", "mean"),
        avg_ranking_opportunity=("ranking_opportunity_score", "mean"),
        avg_decline=("decline_score", "mean"),
        avg_freshness=("freshness_score", "mean"),
        avg_position=("avg_position", "mean")
    )
    .reindex(["Critical", "High", "Medium", "Low"])
)

print(priority_summary)
# Out:
# ===== REFRESH PRIORITY ANALYSIS =====
#
#                   pages  avg_score  median_score  avg_demand  avg_visibility  \
# refresh_priority
# Critical             86  72.329873     71.696019   65.794095       69.675968
# High               1856  62.961497     62.360365   40.449986       63.068412
# Medium            14253  51.718828     51.457842   19.706457       54.685786
# Low               10881  36.633982     38.760676   13.103134       41.421500
#
#                   avg_ranking_opportunity  avg_decline  avg_freshness  \
# refresh_priority
# Critical                        97.209302    79.963962      16.510378
# High                            95.255927    74.806763      14.599845
# Medium                          83.416474    68.396017      13.217346
# Low                             58.950005    46.090709      11.182559
#
#                   avg_position
# refresh_priority
# Critical              7.350000
# High                  7.939170
# Medium               12.885259
# Low                  25.056098

# %%
# ==========================================
# 2. CONTENT TYPE BY PRIORITY
# ==========================================

content_priority = pd.crosstab(
    refresh_queue["content_type"],
    refresh_queue["refresh_priority"],
    normalize="index"
) * 100

print("\n===== CONTENT TYPE × PRIORITY (%) =====")
print(content_priority.round(2))
# Out:
# ===== CONTENT TYPE × PRIORITY (%) =====
# refresh_priority    Critical  High    Low  Medium
# content_type
# comparison article      0.00  0.00  68.01   31.99
# keyword article         0.33  7.04  39.45   53.19

# %%
# ==========================================
# 3. MAIN INTENT BY PRIORITY
# ==========================================

intent_priority = pd.crosstab(
    refresh_queue["main_intent"],
    refresh_queue["refresh_priority"],
    normalize="index"
) * 100

print("\n===== MAIN INTENT × PRIORITY (%) =====")
print(intent_priority.round(2))
# Out:
# ===== MAIN INTENT × PRIORITY (%) =====
# refresh_priority  Critical   High    Low  Medium
# main_intent
# commercial            0.51  10.62  33.24   55.63
# informational         0.33   5.04  44.85   49.78
# navigational          0.00   7.32  58.54   34.15
# transactional         0.14   9.46  31.00   59.39

# %%
# ==========================================
# 4. CRITICAL + HIGH PAGES
# ==========================================

high_priority = refresh_queue[
    refresh_queue["refresh_priority"].isin(["Critical", "High"])
].copy()

print("\n===== CRITICAL + HIGH PAGES =====")
print("Count:", len(high_priority))
print(
    "Percentage:",
    round(len(high_priority) / len(refresh_queue) * 100, 2),
    "%"
)

print("\nContent types:")
print(high_priority["content_type"].value_counts())

print("\nMain intents:")
print(high_priority["main_intent"].value_counts())
# Out:
# ===== CRITICAL + HIGH PAGES =====
# Count: 1942
# Percentage: 7.17 %
#
# Content types:
# content_type
# keyword article    1942
# Name: count, dtype: int64
#
# Main intents:
# main_intent
# informational    904
# transactional    536
# commercial       499
# navigational       3
# Name: count, dtype: int64

# %%
# ==========================================
# HIGH-VALUE REFRESH PATTERNS
# ==========================================

patterns = refresh_queue.copy()

patterns["high_demand"] = patterns["demand_score"] >= 75
patterns["strong_ranking_opportunity"] = (
    patterns["ranking_opportunity_score"] >= 85
)
patterns["significant_decline"] = patterns["decline_score"] >= 75
patterns["high_visibility"] = patterns["visibility_score"] >= 75
patterns["stale_content"] = patterns["freshness_score"] >= 50

print("===== REFRESH SIGNAL COUNTS =====")

print("High demand:",
      patterns["high_demand"].sum())

print("Strong ranking opportunity:",
      patterns["strong_ranking_opportunity"].sum())

print("Significant decline:",
      patterns["significant_decline"].sum())

print("High visibility:",
      patterns["high_visibility"].sum())

print("Stale content:",
      patterns["stale_content"].sum())
# Out:
# ===== REFRESH SIGNAL COUNTS =====
# High demand: 150
# Strong ranking opportunity: 10791
# Significant decline: 8872
# High visibility: 1868
# Stale content: 37

# %%
# Pages satisfying multiple strong signals

patterns["strong_refresh_case"] = (
    patterns["high_demand"].astype(int)
    + patterns["strong_ranking_opportunity"].astype(int)
    + patterns["significant_decline"].astype(int)
    + patterns["high_visibility"].astype(int)
)

print("\n===== MULTI-SIGNAL REFRESH CASES =====")

print(
    patterns["strong_refresh_case"]
    .value_counts()
    .sort_index()
)
# Out:
# ===== MULTI-SIGNAL REFRESH CASES =====
# strong_refresh_case
# 0    10269
# 1    12104
# 2     4534
# 3      167
# 4        2
# Name: count, dtype: int64

# %%
top_100_refresh = (
    refresh_queue
    .sort_values(
        "refresh_opportunity_score",
        ascending=False
    )
    .head(100)
    .copy()
)

print("Top 100 refresh queue shape:")
print(top_100_refresh.shape)

top_100_refresh[
    [
        "refresh_rank",
        "content_id",
        "client_id",
        "content_type",
        "main_intent",
        "search_volume",
        "avg_position",
        "demand_score",
        "visibility_score",
        "ranking_opportunity_score",
        "decline_score",
        "freshness_score",
        "refresh_opportunity_score",
        "refresh_priority",
        "refresh_reason",
        "recommended_action"
    ]
].head(20)
# Out:
# Top 100 refresh queue shape:
# (100, 24)
#     refresh_rank            content_id          client_id     content_type  \
# 0              1  content_8ba781dafa55  client_8527a891e2  keyword article
# 1              2  content_e8fc703f7ef0  client_3fdba35f04  keyword article
# 2              3  content_d0a2a4e36acc  client_19581e27de  keyword article
# 3              4  content_c861e30f2f7a  client_6208ef0f77  keyword article
# 4              5  content_548f0bf562a9  client_3fdba35f04  keyword article
# 5              6  content_2725d2bcfac1  client_4e07408562  keyword article
# 6              7  content_2e0b3dc70916  client_4e07408562  keyword article
# 7              8  content_5fe46e04994d  client_4e07408562  keyword article
# 8              9  content_e6955a2c59dc  client_4e07408562  keyword article
# 9             10  content_2db251d1a841  client_f369cb89fc  keyword article
# 10            11  content_7355102c630d  client_3fdba35f04  keyword article
# 11            12  content_69e07bfa6f0a  client_4e07408562  keyword article
# 12            13  content_d07ea098353c  client_19581e27de  keyword article
# 13            14  content_aaef01a50def  client_19581e27de  keyword article
# 14            15  content_39e33835267d  client_3fdba35f04  keyword article
# 15            16  content_496544bf85aa  client_3fdba35f04  keyword article
# 16            17  content_11fcfd65d94c  client_19581e27de  keyword article
# 17            18  content_3546c7b868f1  client_19581e27de  keyword article
# 18            19  content_c3864767af8f  client_19581e27de  keyword article
# 19            20  content_f421fb2e10ea  client_19581e27de  keyword article
#
#       main_intent  search_volume  avg_position  demand_score  \
# 0   informational         2900.0           9.0     71.110675
# 1   informational         9900.0           9.5     82.059645
# 2      commercial         4400.0           7.6     74.827964
# 3      commercial        22200.0           8.4     89.261870
# 4   informational         9900.0           3.2     82.059645
# 5   informational         6600.0           9.1     78.443692
# 6   informational         9900.0           6.9     82.059645
# 7   informational         1900.0           4.2     67.340771
# 8   informational         3600.0           7.1     73.038603
# 9   informational        14800.0           5.6     85.645668
# 10  informational         8100.0           7.5     80.270033
# 11  informational          880.0           8.7     60.481253
# 12     commercial          390.0           9.4     53.235783
# 13  informational         4400.0           5.4     74.827964
# 14     commercial         6600.0           6.0     78.443692
# 15  informational        14800.0           5.0     85.645668
# 16     commercial          480.0           6.2     55.083471
# 17  informational         4400.0           4.6     74.827964
# 18     commercial          320.0           9.5     51.476335
# 19     commercial         5400.0           5.9     76.654181
#
#     visibility_score  ranking_opportunity_score  decline_score  \
# 0          73.648815                      100.0      92.783717
# 1          59.152539                      100.0      98.253558
# 2          75.633803                      100.0      77.763369
# 3          40.854329                      100.0      93.859649
# 4          76.705544                       85.0      93.476389
# 5          77.649113                      100.0      69.467382
# 6          77.814053                      100.0      58.800795
# 7         100.000000                       85.0      72.395069
# 8          80.055357                      100.0      66.127654
# 9          92.720542                      100.0      48.885880
# 10         75.430771                      100.0      70.487308
# 11         64.131768                      100.0      95.482110
# 12         84.035460                      100.0      84.406729
# 13         99.991098                      100.0      51.982523
# 14         49.469325                      100.0      85.185185
# 15         76.222656                       85.0      75.122517
# 16         90.538119                      100.0      71.139926
# 17         64.889152                       85.0      90.142706
# 18         68.879886                      100.0      95.992560
# 19         38.233399                      100.0      94.852941
#
#     freshness_score  refresh_opportunity_score refresh_priority  \
# 0         27.688172                  78.832992         Critical
# 1          3.494624                  77.345593         Critical
# 2         27.688172                  77.155243         Critical
# 3         27.688172                  77.027080         Critical
# 4         10.752688                  76.876566         Critical
# 5         27.688172                  76.803039         Critical
# 6         27.688172                  75.606698         Critical
# 7         27.688172                  75.333024         Critical
# 8         27.688172                  75.265070         Critical
# 9          5.107527                  75.243454         Critical
# 10         6.720430                  74.923167         Critical
# 11        27.688172                  74.811906         Critical
# 12        27.688172                  74.766201         Critical
# 13         5.645161                  74.666231         Critical
# 14        27.688172                  74.310642         Critical
# 15        10.483871                  73.978839         Critical
# 16        27.688172                  73.875294         Critical
# 17        27.688172                  73.732180         Critical
# 18        27.688172                  73.612390         Critical
# 19        27.688172                  73.549630         Critical
#
#                                        refresh_reason   recommended_action
# 0   strong ranking opportunity; significant perfor...  Refresh immediately
# 1   strong ranking opportunity; significant perfor...  Refresh immediately
# 2   strong ranking opportunity; significant perfor...  Refresh immediately
# 3   strong ranking opportunity; significant perfor...  Refresh immediately
# 4   strong ranking opportunity; significant perfor...  Refresh immediately
# 5   strong ranking opportunity; high search demand...  Refresh immediately
# 6   strong ranking opportunity; high search demand...  Refresh immediately
# 7   strong ranking opportunity; strong existing vi...  Refresh immediately
# 8   strong ranking opportunity; high search demand...  Refresh immediately
# 9   strong ranking opportunity; high search demand...  Refresh immediately
# 10  strong ranking opportunity; high search demand...  Refresh immediately
# 11  strong ranking opportunity; significant perfor...  Refresh immediately
# 12  strong ranking opportunity; significant perfor...  Refresh immediately
# 13  strong ranking opportunity; high search demand...  Refresh immediately
# 14  strong ranking opportunity; significant perfor...  Refresh immediately
# 15  strong ranking opportunity; significant perfor...  Refresh immediately
# 16  strong ranking opportunity; strong existing vi...  Refresh immediately
# 17  strong ranking opportunity; significant perfor...  Refresh immediately
# 18  strong ranking opportunity; significant perfor...  Refresh immediately
# 19  strong ranking opportunity; significant perfor...  Refresh immediately

# %%
OUTPUT_PATH = "refresh_priority_queue.csv"

refresh_queue.to_csv(
    OUTPUT_PATH,
    index=False
)

print("Saved:", OUTPUT_PATH)
print("Rows:", len(refresh_queue))
print("Columns:", len(refresh_queue.columns))
# Out:
# Saved: refresh_priority_queue.csv
# Rows: 27076
# Columns: 24

# %%
import os

print("File exists:", os.path.exists(OUTPUT_PATH))

if os.path.exists(OUTPUT_PATH):
    print("File size:", round(os.path.getsize(OUTPUT_PATH) / 1024 / 1024, 2), "MB")
# Out:
# File exists: True
# File size: 6.61 MB

# %%
HIGH_PRIORITY_PATH = "high_priority_refresh_queue.csv"

high_priority.to_csv(
    HIGH_PRIORITY_PATH,
    index=False
)

print("Saved:", HIGH_PRIORITY_PATH)
print("Rows:", len(high_priority))
# Out:
# Saved: high_priority_refresh_queue.csv
# Rows: 1942

# %%
print("===== REFRESH QUEUE COLUMNS =====")

print(refresh_queue.columns.tolist())
# Out:
# ===== REFRESH QUEUE COLUMNS =====
# ['refresh_rank', 'content_id', 'client_id', 'content_type', 'main_intent', 'search_volume', 'competition', 'impressions_90d', 'clicks_90d', 'avg_position', 'days_since_last_update', 'impressions_last_30d', 'impressions_prev_30d', 'clicks_last_30d', 'clicks_prev_30d', 'demand_score', 'visibility_score', 'ranking_opportunity_score', 'decline_score', 'freshness_score', 'refresh_opportunity_score', 'refresh_priority', 'refresh_reason', 'recommended_action']

# %%
print("===== EXTREME IMPRESSION CHANGE VALIDATION =====")

validation_df = refresh_queue.copy()

# Recalculate relative impression change for validation
# Small epsilon prevents division by zero
epsilon = 1e-6

validation_df["relative_impression_change"] = (
    validation_df["impressions_last_30d"] -
    validation_df["impressions_prev_30d"]
) / (
    validation_df["impressions_prev_30d"] + epsilon
)

extreme_summary = validation_df[
    [
        "relative_impression_change",
        "decline_score",
        "refresh_opportunity_score"
    ]
].describe(
    percentiles=[0.90, 0.95, 0.99, 0.995, 0.999]
)

print(extreme_summary)
# Out:
# ===== EXTREME IMPRESSION CHANGE VALIDATION =====
#        relative_impression_change  decline_score  refresh_opportunity_score
# count                2.707600e+04   27076.000000               27076.000000
# mean                 1.309514e+07      59.908394                  46.492825
# std                  3.236634e+08      25.823893                  10.209673
# min                 -1.000000e+00       0.000000                   6.564393
# 50%                 -2.956013e-01      64.587392                  47.416202
# 90%                  6.603034e-01      88.954389                  58.631203
# 95%                  1.999998e+00      93.536351                  61.317116
# 99%                  1.325000e+07      98.387097                  66.664089
# 99.5%                2.715000e+08      99.060017                  68.667249
# 99.9%                3.404525e+09      99.618100                  72.964317
# max                  3.095300e+10      99.974581                  78.832992

# %%
print("===== ZERO PREVIOUS IMPRESSIONS VALIDATION =====")

zero_prev = refresh_queue["impressions_prev_30d"].eq(0)

print("Rows with previous 30d impressions = 0:",
      zero_prev.sum())

print("Percentage:",
      round(zero_prev.mean() * 100, 2), "%")

print("\nRows with previous impressions > 0:",
      (~zero_prev).sum())
# Out:
# ===== ZERO PREVIOUS IMPRESSIONS VALIDATION =====
# Rows with previous 30d impressions = 0: 1795
# Percentage: 6.63 %
#
# Rows with previous impressions > 0: 25281

# %%
print("===== CHANGE TYPE BREAKDOWN =====")

print(
    pd.Series(
        np.where(
            refresh_queue["impressions_prev_30d"] == 0,
            "Zero previous impressions",
            "Normal baseline"
        )
    ).value_counts()
)
# Out:
# ===== CHANGE TYPE BREAKDOWN =====
# Normal baseline              25281
# Zero previous impressions     1795
# Name: count, dtype: int64

# %%
print("===== EXTREME CHANGES WITH NON-ZERO BASELINE =====")

nonzero_prev = refresh_queue[
    refresh_queue["impressions_prev_30d"] > 0
].copy()

nonzero_prev["relative_impression_change"] = (
    (nonzero_prev["impressions_last_30d"] -
     nonzero_prev["impressions_prev_30d"])
    / nonzero_prev["impressions_prev_30d"]
)

print(
    nonzero_prev["relative_impression_change"].describe(
        percentiles=[0.01, 0.05, 0.50, 0.90, 0.95, 0.99, 0.999]
    )
)
# Out:
# ===== EXTREME CHANGES WITH NON-ZERO BASELINE =====
# count    25281.000000
# mean        -0.052623
# std          4.843903
# min         -1.000000
# 1%          -1.000000
# 5%          -0.981928
# 50%         -0.336170
# 90%          0.481013
# 95%          1.000000
# 99%          3.501818
# 99.9%       34.884932
# max        449.000000
# Name: relative_impression_change, dtype: float64

# %%
print("===== TOP NON-ZERO-BASELINE GROWTH =====")

top_growth = nonzero_prev.sort_values(
    "relative_impression_change",
    ascending=False
)[
    [
        "content_id",
        "impressions_last_30d",
        "impressions_prev_30d",
        "relative_impression_change",
        "decline_score",
        "refresh_opportunity_score"
    ]
].head(20)

display(top_growth)
# Out:
# ===== TOP NON-ZERO-BASELINE GROWTH =====
#                  content_id  impressions_last_30d  impressions_prev_30d  \
# 26264  content_dd882c4152ac                   450                     1
# 26279  content_a023517539fe                212015                   757
# 25916  content_d020d42e7fcc                  2364                     9
# 25564  content_22f4d2f58c42                   215                     1
# 18049  content_4f1966b37335                  1546                     9
# 24449  content_aac5bd559d85                  1274                     8
# 19046  content_32ff84795595                   150                     1
# 22716  content_ceedad7ba6dc                   470                     4
# 22565  content_a6c4ef450727                   341                     3
# 26395  content_f6e1f66b051e                   227                     2
# 17637  content_f511aa26fadf                   304                     3
# 24512  content_f560a011a094                    85                     1
# 26452  content_e05c35868281                    76                     1
# 26101  content_94feac677ec4                   505                     8
# 25048  content_a869de96aa65                    61                     1
# 26998  content_7356ccaee391                   119                     2
# 15868  content_c560a19bd235                  1201                    21
# 25305  content_4a6607efcb46                122303                  2213
# 23079  content_32906302c1ed                  1161                    26
# 25832  content_b5c3a038ee4b                    88                     2
#
#        relative_impression_change  decline_score  refresh_opportunity_score
# 26264                  449.000000            0.0                  24.338890
# 26279                  279.072655            0.0                  24.168176
# 25916                  261.666667            0.0                  26.424691
# 25564                  214.000000            0.0                  28.366059
# 18049                  170.777778            0.0                  43.105425
# 24449                  158.250000            0.0                  32.511718
# 19046                  149.000000            0.0                  41.976551
# 22716                  116.500000            0.0                  36.931885
# 22565                  112.666667            0.0                  37.245764
# 26395                  112.500000            0.0                  23.402603
# 17637                  100.333333            0.0                  43.570917
# 24512                   84.000000            0.0                  32.299301
# 26452                   75.000000            0.0                  22.767889
# 26101                   62.125000            0.0                  25.369336
# 25048                   60.000000            0.0                  30.343338
# 26998                   58.500000            0.0                  12.813260
# 15868                   56.190476            0.0                  45.343714
# 25305                   54.265703            0.0                  29.395479
# 23079                   43.653846            0.0                  36.233800
# 25832                   43.000000            0.0                  27.094354

# %%
print("===== DECLINE SCORE VALIDATION =====")

print("High decline cases:")
display(
    refresh_queue.sort_values(
        "decline_score",
        ascending=False
    )[
        [
            "content_id",
            "impressions_last_30d",
            "impressions_prev_30d",
            "decline_score",
            "refresh_opportunity_score"
        ]
    ].head(10)
)

print("\nGrowth cases:")
display(
    refresh_queue.sort_values(
        "decline_score",
        ascending=True
    )[
        [
            "content_id",
            "impressions_last_30d",
            "impressions_prev_30d",
            "decline_score",
            "refresh_opportunity_score"
        ]
    ].head(10)
)
# Out:
# ===== DECLINE SCORE VALIDATION =====
# High decline cases:
#                  content_id  impressions_last_30d  impressions_prev_30d  \
# 762    content_331a01416e92                     0                  1966
# 9401   content_8679ea39fb73                     0                   291
# 6938   content_581f405133c1                     1                   573
# 1186   content_6c5a581c33ce                     0                   232
# 14927  content_2a57f2016a14                     9                  2234
# 7309   content_506693a2cdd2                     0                   204
# 4489   content_d4d39a028c6b                     0                   202
# 11854  content_dafc478c3257                     0                   171
# 373    content_9bbf99b4dc21                     0                   165
# 6393   content_9f180a1406cc                     0                   164
#
#        decline_score  refresh_opportunity_score
# 762        99.974581                  63.237982
# 9401       99.828767                  51.149688
# 6938       99.825784                  53.495774
# 1186       99.785408                  61.816385
# 14927      99.776286                  46.211277
# 7309       99.756098                  53.141028
# 4489       99.753695                  56.126370
# 11854      99.709302                  48.902333
# 373        99.698795                  65.642448
# 6393       99.696970                  54.023396
# Growth cases:
#                  content_id  impressions_last_30d  impressions_prev_30d  \
# 16793  content_01c129ed7519                  2810                  1319
# 25491  content_36e6a6365d61                   855                     0
# 25519  content_4f7475e978b3                    93                    41
# 25513  content_35e5aae78ac3                   393                   186
# 25479  content_d0b3e7ec062a                     1                     0
# 25478  content_c2d256c891ad                     2                     0
# 25477  content_c8e7e069617c                     6                     1
# 22843  content_3045d7ffc66d                    41                     4
# 22840  content_b35a2fccc71a                  1241                     0
# 25492  content_424ff4ad540a                     3                     1
#
#        decline_score  refresh_opportunity_score
# 16793            0.0                  44.416795
# 25491            0.0                  28.621555
# 25519            0.0                  28.526131
# 25513            0.0                  28.547567
# 25479            0.0                  28.671675
# 25478            0.0                  28.671675
# 25477            0.0                  28.671675
# 22843            0.0                  36.677398
# 22840            0.0                  36.687342
# 25492            0.0                  28.617631

# %%
print("===== SMALL BASELINE VALIDATION =====")

baseline = refresh_queue["impressions_prev_30d"]

print("\nPrevious-period impression distribution:")

print(
    baseline.describe(
        percentiles=[0.01, 0.05, 0.10, 0.25, 0.50, 0.75]
    )
)

print("\nRows by previous-period impression range:")

baseline_groups = pd.cut(
    baseline,
    bins=[-1, 0, 1, 5, 10, 25, 50, 100, 500, 1000, float("inf")],
    labels=[
        "0",
        "1",
        "2-5",
        "6-10",
        "11-25",
        "26-50",
        "51-100",
        "101-500",
        "501-1000",
        "1000+"
    ]
)

print(baseline_groups.value_counts().sort_index())
# Out:
# ===== SMALL BASELINE VALIDATION =====
#
# Previous-period impression distribution:
# count     27076.000000
# mean       1960.893190
# std        6441.582606
# min           0.000000
# 1%            0.000000
# 5%            0.000000
# 10%           3.000000
# 25%          41.000000
# 50%         280.000000
# 75%        1338.000000
# max      218786.000000
# Name: impressions_prev_30d, dtype: float64
#
# Rows by previous-period impression range:
# impressions_prev_30d
# 0           1795
# 1            461
# 2-5         1171
# 6-10         815
# 11-25       1504
# 26-50       1587
# 51-100      2102
# 101-500     6655
# 501-1000    3042
# 1000+       7944
# Name: count, dtype: int64

# %%
print("===== EXTREME GROWTH IMPACT VALIDATION =====")

growth_check = refresh_queue[
    refresh_queue["impressions_prev_30d"] > 0
].copy()

growth_check["relative_impression_change"] = (
    (growth_check["impressions_last_30d"] -
     growth_check["impressions_prev_30d"])
    / growth_check["impressions_prev_30d"]
)

# Extreme growth = more than 1000% increase
extreme_growth = growth_check[
    growth_check["relative_impression_change"] >= 10
].copy()

print("Pages with >1000% impression growth:",
      len(extreme_growth))

print(
    "Percentage of non-zero-baseline pages:",
    round(
        len(extreme_growth) /
        len(growth_check) * 100,
        2
    ),
    "%"
)

print("\nPriority distribution:")

print(
    extreme_growth["refresh_priority"]
    .value_counts()
    .reindex(
        ["Critical", "High", "Medium", "Low"],
        fill_value=0
    )
)

print("\nAverage scores:")

print(
    extreme_growth[
        [
            "decline_score",
            "refresh_opportunity_score"
        ]
    ].mean()
)
# Out:
# ===== EXTREME GROWTH IMPACT VALIDATION =====
# Pages with >1000% impression growth: 80
# Percentage of non-zero-baseline pages: 0.32 %
#
# Priority distribution:
# refresh_priority
# Critical     0
# High         0
# Medium       7
# Low         73
# Name: count, dtype: int64
#
# Average scores:
# decline_score                 0.000000
# refresh_opportunity_score    33.904191
# dtype: float64

# %%
print("===== SMALL BASELINE EXTREME GROWTH =====")

small_baseline_growth = growth_check[
    (growth_check["impressions_prev_30d"] <= 10) &
    (growth_check["relative_impression_change"] >= 10)
].copy()

print(
    "Small-baseline extreme growth pages:",
    len(small_baseline_growth)
)

print("\nPriority distribution:")

print(
    small_baseline_growth["refresh_priority"]
    .value_counts()
    .reindex(
        ["Critical", "High", "Medium", "Low"],
        fill_value=0
    )
)

print("\nTop examples:")

display(
    small_baseline_growth.sort_values(
        "relative_impression_change",
        ascending=False
    )[
        [
            "content_id",
            "impressions_prev_30d",
            "impressions_last_30d",
            "relative_impression_change",
            "decline_score",
            "refresh_opportunity_score",
            "refresh_priority"
        ]
    ].head(20)
)
# Out:
# ===== SMALL BASELINE EXTREME GROWTH =====
# Small-baseline extreme growth pages: 46
#
# Priority distribution:
# refresh_priority
# Critical     0
# High         0
# Medium       2
# Low         44
# Name: count, dtype: int64
#
# Top examples:
#                  content_id  impressions_prev_30d  impressions_last_30d  \
# 26264  content_dd882c4152ac                     1                   450
# 25916  content_d020d42e7fcc                     9                  2364
# 25564  content_22f4d2f58c42                     1                   215
# 18049  content_4f1966b37335                     9                  1546
# 24449  content_aac5bd559d85                     8                  1274
# 19046  content_32ff84795595                     1                   150
# 22716  content_ceedad7ba6dc                     4                   470
# 22565  content_a6c4ef450727                     3                   341
# 26395  content_f6e1f66b051e                     2                   227
# 17637  content_f511aa26fadf                     3                   304
# 24512  content_f560a011a094                     1                    85
# 26452  content_e05c35868281                     1                    76
# 26101  content_94feac677ec4                     8                   505
# 25048  content_a869de96aa65                     1                    61
# 26998  content_7356ccaee391                     2                   119
# 25832  content_b5c3a038ee4b                     2                    88
# 20772  content_6c3884073301                     8                   331
# 23959  content_f8d0a67e22fc                     5                   206
# 27013  content_23077e0641b0                     2                    78
# 25763  content_eb4c8f7b7466                     2                    78
#
#        relative_impression_change  decline_score  refresh_opportunity_score  \
# 26264                  449.000000            0.0                  24.338890
# 25916                  261.666667            0.0                  26.424691
# 25564                  214.000000            0.0                  28.366059
# 18049                  170.777778            0.0                  43.105425
# 24449                  158.250000            0.0                  32.511718
# 19046                  149.000000            0.0                  41.976551
# 22716                  116.500000            0.0                  36.931885
# 22565                  112.666667            0.0                  37.245764
# 26395                  112.500000            0.0                  23.402603
# 17637                  100.333333            0.0                  43.570917
# 24512                   84.000000            0.0                  32.299301
# 26452                   75.000000            0.0                  22.767889
# 26101                   62.125000            0.0                  25.369336
# 25048                   60.000000            0.0                  30.343338
# 26998                   58.500000            0.0                  12.813260
# 25832                   43.000000            0.0                  27.094354
# 20772                   40.375000            0.0                  39.937543
# 23959                   40.200000            0.0                  34.090467
# 27013                   38.000000            0.0                  12.190677
# 25763                   38.000000            0.0                  27.405731
#
#       refresh_priority
# 26264              Low
# 25916              Low
# 25564              Low
# 18049              Low
# 24449              Low
# 19046              Low
# 22716              Low
# 22565              Low
# 26395              Low
# 17637              Low
# 24512              Low
# 26452              Low
# 26101              Low
# 25048              Low
# 26998              Low
# 25832              Low
# 20772              Low
# 23959              Low
# 27013              Low
# 25763              Low

# %%
print("===== EXTREME DECLINE IMPACT VALIDATION =====")

decline_check = refresh_queue[
    refresh_queue["impressions_prev_30d"] > 0
].copy()

decline_check["relative_impression_change"] = (
    (decline_check["impressions_last_30d"] -
     decline_check["impressions_prev_30d"])
    / decline_check["impressions_prev_30d"]
)

# Pages with 75% or greater decline
extreme_declines = decline_check[
    decline_check["relative_impression_change"] <= -0.75
].copy()

print("Pages with >=75% impression decline:",
      len(extreme_declines))

print(
    "Percentage of non-zero-baseline pages:",
    round(
        len(extreme_declines) /
        len(decline_check) * 100,
        2
    ),
    "%"
)

print("\nAverage decline score:")

print(
    round(
        extreme_declines["decline_score"].mean(),
        2
    )
)

print("\nAverage refresh opportunity score:")

print(
    round(
        extreme_declines["refresh_opportunity_score"].mean(),
        2
    )
)

print("\nPriority distribution:")

print(
    extreme_declines["refresh_priority"]
    .value_counts()
    .reindex(
        ["Critical", "High", "Medium", "Low"],
        fill_value=0
    )
)
# Out:
# ===== EXTREME DECLINE IMPACT VALIDATION =====
# Pages with >=75% impression decline: 3928
# Percentage of non-zero-baseline pages: 15.54 %
#
# Average decline score:
# 90.95
#
# Average refresh opportunity score:
# 49.91
#
# Priority distribution:
# refresh_priority
# Critical      31
# High         395
# Medium      2464
# Low         1038
# Name: count, dtype: int64

# %%
print("===== WORST DECLINE EXAMPLES =====")

display(
    extreme_declines.sort_values(
        "decline_score",
        ascending=False
    )[
        [
            "content_id",
            "impressions_prev_30d",
            "impressions_last_30d",
            "relative_impression_change",
            "decline_score",
            "ranking_opportunity_score",
            "freshness_score",
            "refresh_opportunity_score",
            "refresh_priority"
        ]
    ].head(20)
)
# Out:
# ===== WORST DECLINE EXAMPLES =====
#                  content_id  impressions_prev_30d  impressions_last_30d  \
# 762    content_331a01416e92                  1966                     0
# 9401   content_8679ea39fb73                   291                     0
# 6938   content_581f405133c1                   573                     1
# 1186   content_6c5a581c33ce                   232                     0
# 14927  content_2a57f2016a14                  2234                     9
# 7309   content_506693a2cdd2                   204                     0
# 4489   content_d4d39a028c6b                   202                     0
# 11854  content_dafc478c3257                   171                     0
# 373    content_9bbf99b4dc21                   165                     0
# 6393   content_9f180a1406cc                   164                     0
# 2278   content_3389e4cff48b                   163                     0
# 19656  content_56de85247382                   163                     0
# 11485  content_8fb79a8290e8                   311                     1
# 1391   content_ab11e71992b7                   154                     0
# 1446   content_07f879e82acd                   149                     0
# 12339  content_71bd6c21d4a5                   299                     1
# 12246  content_f91533dcfe3f                   147                     0
# 5357   content_1e446b05f1c5                   293                     1
# 18484  content_611d55167bba                   289                     1
# 2703   content_7bd0e1aa7b13                   687                     4
#
#        relative_impression_change  decline_score  ranking_opportunity_score  \
# 762                     -1.000000      99.974581                       85.0
# 9401                    -1.000000      99.828767                       50.0
# 6938                    -0.998255      99.825784                       80.0
# 1186                    -1.000000      99.785408                      100.0
# 14927                   -0.995971      99.776286                       35.0
# 7309                    -1.000000      99.756098                       20.0
# 4489                    -1.000000      99.753695                       80.0
# 11854                   -1.000000      99.709302                       50.0
# 373                     -1.000000      99.698795                      100.0
# 6393                    -1.000000      99.696970                      100.0
# 2278                    -1.000000      99.695122                      100.0
# 19656                   -1.000000      99.695122                       20.0
# 11485                   -0.996785      99.679487                       80.0
# 1391                    -1.000000      99.677419                      100.0
# 1446                    -1.000000      99.666667                      100.0
# 12339                   -0.996656      99.666667                       50.0
# 12246                   -1.000000      99.662162                       50.0
# 5357                    -0.996587      99.659864                       50.0
# 18484                   -0.996540      99.655172                       50.0
# 2703                    -0.994178      99.636628                       80.0
#
#        freshness_score  refresh_opportunity_score refresh_priority
# 762          27.688172                  63.237982             High
# 9401          1.881720                  51.149688           Medium
# 6938          7.258065                  53.495774           Medium
# 1186          1.881720                  61.816385             High
# 14927         3.763441                  46.211277           Medium
# 7309         27.688172                  53.141028           Medium
# 4489          5.107527                  56.126370           Medium
# 11854         1.881720                  48.902333           Medium
# 373           1.881720                  65.642448             High
# 6393          1.881720                  54.023396           Medium
# 2278          5.107527                  59.340045           Medium
# 19656         1.881720                  41.309814              Low
# 11485         5.107527                  49.233856           Medium
# 1391          1.881720                  61.242142             High
# 1446          5.107527                  61.084231             High
# 12339         5.107527                  48.489576           Medium
# 12246         1.881720                  48.567500           Medium
# 5357         27.688172                  55.186517           Medium
# 18484         7.258065                  42.639608              Low
# 2703         27.688172                  58.640448           Medium

# %%
print("===== PRIORITY ORDERING VALIDATION =====")

priority_order = ["Critical", "High", "Medium", "Low"]

priority_summary = (
    refresh_queue
    .groupby("refresh_priority")
    .agg(
        pages=("content_id", "count"),
        avg_refresh_score=("refresh_opportunity_score", "mean"),
        median_refresh_score=("refresh_opportunity_score", "median"),
        avg_demand=("demand_score", "mean"),
        avg_visibility=("visibility_score", "mean"),
        avg_ranking_opportunity=("ranking_opportunity_score", "mean"),
        avg_decline=("decline_score", "mean"),
        avg_freshness=("freshness_score", "mean"),
        avg_position=("avg_position", "mean")
    )
    .reindex(priority_order)
)

print(priority_summary)
# Out:
# ===== PRIORITY ORDERING VALIDATION =====
#                   pages  avg_refresh_score  median_refresh_score  avg_demand  \
# refresh_priority
# Critical             86          72.329873             71.696019   65.794095
# High               1856          62.961497             62.360365   40.449986
# Medium            14253          51.718828             51.457842   19.706457
# Low               10881          36.633982             38.760676   13.103134
#
#                   avg_visibility  avg_ranking_opportunity  avg_decline  \
# refresh_priority
# Critical               69.675968                97.209302    79.963962
# High                   63.068412                95.255927    74.806763
# Medium                 54.685786                83.416474    68.396017
# Low                    41.421500                58.950005    46.090709
#
#                   avg_freshness  avg_position
# refresh_priority
# Critical              16.510378      7.350000
# High                  14.599845      7.939170
# Medium                13.217346     12.885259
# Low                   11.182559     25.056098

# %%
print("\n===== SCORE MONOTONICITY CHECK =====")

scores = priority_summary["avg_refresh_score"]

print("Critical > High:", scores["Critical"] > scores["High"])
print("High > Medium:", scores["High"] > scores["Medium"])
print("Medium > Low:", scores["Medium"] > scores["Low"])

if (
    scores["Critical"] > scores["High"]
    and scores["High"] > scores["Medium"]
    and scores["Medium"] > scores["Low"]
):
    print("PASS — priority ordering is monotonic.")
else:
    print("WARNING — priority ordering is not fully monotonic.")
# Out:
# ===== SCORE MONOTONICITY CHECK =====
# Critical > High: True
# High > Medium: True
# Medium > Low: True
# PASS — priority ordering is monotonic.

# %%
print("\n===== PRIORITY COMPONENT VALIDATION =====")

for col in [
    "demand_score",
    "visibility_score",
    "ranking_opportunity_score",
    "decline_score",
    "freshness_score"
]:
    print(f"\n{col}:")
    print(
        refresh_queue
        .groupby("refresh_priority")[col]
        .mean()
        .reindex(priority_order)
    )
# Out:
# ===== PRIORITY COMPONENT VALIDATION =====
#
# demand_score:
# refresh_priority
# Critical    65.794095
# High        40.449986
# Medium      19.706457
# Low         13.103134
# Name: demand_score, dtype: float64
#
# visibility_score:
# refresh_priority
# Critical    69.675968
# High        63.068412
# Medium      54.685786
# Low         41.421500
# Name: visibility_score, dtype: float64
#
# ranking_opportunity_score:
# refresh_priority
# Critical    97.209302
# High        95.255927
# Medium      83.416474
# Low         58.950005
# Name: ranking_opportunity_score, dtype: float64
#
# decline_score:
# refresh_priority
# Critical    79.963962
# High        74.806763
# Medium      68.396017
# Low         46.090709
# Name: decline_score, dtype: float64
#
# freshness_score:
# refresh_priority
# Critical    16.510378
# High        14.599845
# Medium      13.217346
# Low         11.182559
# Name: freshness_score, dtype: float64

# %%
print("===== CRITICAL ACTIONABILITY VALIDATION =====")

critical = refresh_queue[
    refresh_queue["refresh_priority"] == "Critical"
].copy()

print("Critical pages:", len(critical))

print("\nCritical pages with ranking opportunity >= 85:")
print(
    (critical["ranking_opportunity_score"] >= 85).sum(),
    f"({(critical['ranking_opportunity_score'] >= 85).mean() * 100:.2f}%)"
)

print("\nCritical pages with decline score >= 75:")
print(
    (critical["decline_score"] >= 75).sum(),
    f"({(critical['decline_score'] >= 75).mean() * 100:.2f}%)"
)

print("\nCritical pages with demand score >= 50:")
print(
    (critical["demand_score"] >= 50).sum(),
    f"({(critical['demand_score'] >= 50).mean() * 100:.2f}%)"
)

print("\nCritical pages with avg position <= 10:")
print(
    (critical["avg_position"] <= 10).sum(),
    f"({(critical['avg_position'] <= 10).mean() * 100:.2f}%)"
)
# Out:
# ===== CRITICAL ACTIONABILITY VALIDATION =====
# Critical pages: 86
#
# Critical pages with ranking opportunity >= 85:
# 80 (93.02%)
#
# Critical pages with decline score >= 75:
# 58 (67.44%)
#
# Critical pages with demand score >= 50:
# 76 (88.37%)
#
# Critical pages with avg position <= 10:
# 80 (93.02%)

# %%
print("===== REFRESH REASON / ACTION VALIDATION =====")

print("\nReason distribution:")
print(refresh_queue["refresh_reason"].value_counts())

print("\nRecommended action distribution:")
print(refresh_queue["recommended_action"].value_counts())

print("\nPriority vs recommended action:")
print(
    pd.crosstab(
        refresh_queue["refresh_priority"],
        refresh_queue["recommended_action"],
        normalize="index"
    ).round(3)
)
# Out:
# ===== REFRESH REASON / ACTION VALIDATION =====
#
# Reason distribution:
# refresh_reason
# moderate refresh opportunity                                                                                   9624
# strong ranking opportunity                                                                                     5599
# significant performance decline                                                                                4895
# strong ranking opportunity; significant performance decline                                                    3085
# strong ranking opportunity; strong existing visibility                                                         1705
# strong existing visibility                                                                                     1051
# significant performance decline; strong existing visibility                                                     464
# strong ranking opportunity; significant performance decline; strong existing visibility                         323
# high search demand                                                                                              155
# significant performance decline; high search demand                                                              50
# strong ranking opportunity; high search demand                                                                   36
# strong ranking opportunity; significant performance decline; high search demand                                  21
# content is stale                                                                                                 14
# significant performance decline; content is stale                                                                14
# strong ranking opportunity; high search demand; strong existing visibility                                       12
# high search demand; strong existing visibility                                                                    7
# significant performance decline; high search demand; strong existing visibility                                   7
# strong ranking opportunity; significant performance decline; high search demand; strong existing visibility       5
# strong ranking opportunity; significant performance decline; content is stale                                     4
# significant performance decline; content is stale; strong existing visibility                                     4
# strong ranking opportunity; content is stale                                                                      1
# Name: count, dtype: int64
#
# Recommended action distribution:
# recommended_action
# Schedule refresh / monitor    14253
# Monitor                       10881
# Refresh next                   1856
# Refresh immediately              86
# Name: count, dtype: int64
#
# Priority vs recommended action:
# recommended_action  Monitor  Refresh immediately  Refresh next  \
# refresh_priority
# Critical                0.0                  1.0           0.0
# High                    0.0                  0.0           1.0
# Low                     1.0                  0.0           0.0
# Medium                  0.0                  0.0           0.0
#
# recommended_action  Schedule refresh / monitor
# refresh_priority
# Critical                                   0.0
# High                                       0.0
# Low                                        0.0
# Medium                                     1.0

# %%
print("\n===== PRIORITY / ACTION CONSISTENCY =====")

expected_actions = {
    "Critical": "Refresh immediately",
    "High": "Refresh soon",
    "Medium": "Consider refresh",
    "Low": "Monitor"
}

for priority, expected_action in expected_actions.items():
    subset = refresh_queue[
        refresh_queue["refresh_priority"] == priority
    ]

    if len(subset) == 0:
        print(f"{priority}: No pages")
        continue

    matches = (subset["recommended_action"] == expected_action).sum()
    total = len(subset)

    print(
        f"{priority}: {matches}/{total} "
        f"({matches/total*100:.2f}%) match expected action"
    )
# Out:
# ===== PRIORITY / ACTION CONSISTENCY =====
# Critical: 86/86 (100.00%) match expected action
# High: 0/1856 (0.00%) match expected action
# Medium: 0/14253 (0.00%) match expected action
# Low: 10881/10881 (100.00%) match expected action

# %%
print("\n===== CRITICAL REASON SANITY CHECK =====")

critical = refresh_queue[
    refresh_queue["refresh_priority"] == "Critical"
].copy()

print("Critical pages:", len(critical))

print("\nSample critical reasons:")
for reason in critical["refresh_reason"].head(20):
    print("-", reason)
# Out:
# ===== CRITICAL REASON SANITY CHECK =====
# Critical pages: 86
#
# Sample critical reasons:
# - strong ranking opportunity; significant performance decline; high search demand; strong existing visibility
# - strong ranking opportunity; significant performance decline; high search demand
# - strong ranking opportunity; significant performance decline; high search demand; strong existing visibility
# - strong ranking opportunity; significant performance decline; high search demand
# - strong ranking opportunity; significant performance decline; high search demand; strong existing visibility
# - strong ranking opportunity; high search demand; strong existing visibility
# - strong ranking opportunity; high search demand; strong existing visibility
# - strong ranking opportunity; strong existing visibility
# - strong ranking opportunity; high search demand; strong existing visibility
# - strong ranking opportunity; high search demand; strong existing visibility
# - strong ranking opportunity; high search demand; strong existing visibility
# - strong ranking opportunity; significant performance decline
# - strong ranking opportunity; significant performance decline; strong existing visibility
# - strong ranking opportunity; high search demand; strong existing visibility
# - strong ranking opportunity; significant performance decline; high search demand
# - strong ranking opportunity; significant performance decline; high search demand; strong existing visibility
# - strong ranking opportunity; strong existing visibility
# - strong ranking opportunity; significant performance decline; high search demand
# - strong ranking opportunity; significant performance decline
# - strong ranking opportunity; significant performance decline; high search demand

# %%
print("===== CORRECTED PRIORITY / ACTION CONSISTENCY =====")

expected_actions = {
    "Critical": "Refresh immediately",
    "High": "Refresh next",
    "Medium": "Schedule refresh / monitor",
    "Low": "Monitor"
}

all_pass = True

for priority, expected_action in expected_actions.items():
    subset = refresh_queue[
        refresh_queue["refresh_priority"] == priority
    ]

    matches = (
        subset["recommended_action"] == expected_action
    ).sum()

    total = len(subset)
    percentage = matches / total * 100

    passed = matches == total
    all_pass = all_pass and passed

    print(
        f"{priority}: {matches}/{total} "
        f"({percentage:.2f}%) "
        f"{'PASS' if passed else 'FAIL'}"
    )

print(
    "\nOVERALL:",
    "PASS — all priorities map to the correct action."
    if all_pass
    else "FAIL — action mapping needs investigation."
)
# Out:
# ===== CORRECTED PRIORITY / ACTION CONSISTENCY =====
# Critical: 86/86 (100.00%) PASS
# High: 1856/1856 (100.00%) PASS
# Medium: 14253/14253 (100.00%) PASS
# Low: 10881/10881 (100.00%) PASS
#
# OVERALL: PASS — all priorities map to the correct action.

# %%
print("===== CRITICAL REASON COMPONENT VALIDATION =====")

critical = refresh_queue[
    refresh_queue["refresh_priority"] == "Critical"
].copy()

checks = {
    "High ranking opportunity": (
        critical["ranking_opportunity_score"] >= 85
    ),
    "High demand": (
        critical["demand_score"] >= 50
    ),
    "Significant decline": (
        critical["decline_score"] >= 75
    ),
    "Strong visibility": (
        critical["visibility_score"] >= 70
    )
}

for name, condition in checks.items():
    count = condition.sum()
    percentage = condition.mean() * 100

    print(
        f"{name}: {count}/{len(critical)} "
        f"({percentage:.2f}%)"
    )
# Out:
# ===== CRITICAL REASON COMPONENT VALIDATION =====
# High ranking opportunity: 80/86 (93.02%)
# High demand: 76/86 (88.37%)
# Significant decline: 58/86 (67.44%)
# Strong visibility: 46/86 (53.49%)

# %%
print("===== REASON CONSISTENCY CHECK =====")

# Pages claiming significant decline
decline_reason = refresh_queue[
    refresh_queue["refresh_reason"].str.contains(
        "significant performance decline",
        case=False,
        na=False
    )
]

print(
    "Pages claiming significant decline:",
    len(decline_reason)
)

print(
    "Mean decline score:",
    decline_reason["decline_score"].mean()
)

print(
    "Minimum decline score:",
    decline_reason["decline_score"].min()
)

# Pages claiming high search demand
demand_reason = refresh_queue[
    refresh_queue["refresh_reason"].str.contains(
        "high search demand",
        case=False,
        na=False
    )
]

print(
    "\nPages claiming high search demand:",
    len(demand_reason)
)

print(
    "Mean demand score:",
    demand_reason["demand_score"].mean()
)

print(
    "Minimum demand score:",
    demand_reason["demand_score"].min()
)
# Out:
# ===== REASON CONSISTENCY CHECK =====
# Pages claiming significant decline: 8872
# Mean decline score: 85.15947918196521
# Minimum decline score: 75.0
#
# Pages claiming high search demand: 293
# Mean demand score: 78.12044282345619
# Minimum demand score: 71.11067525139921

# %%
print("===== RANKING REASON CONSISTENCY =====")

ranking_reason = refresh_queue[
    refresh_queue["refresh_reason"].str.contains(
        "strong ranking opportunity",
        case=False,
        na=False
    )
]

print(
    "Pages claiming strong ranking opportunity:",
    len(ranking_reason)
)

print(
    "Mean ranking opportunity score:",
    ranking_reason["ranking_opportunity_score"].mean()
)

print(
    "Minimum ranking opportunity score:",
    ranking_reason["ranking_opportunity_score"].min()
)
# Out:
# ===== RANKING REASON CONSISTENCY =====
# Pages claiming strong ranking opportunity: 10791
# Mean ranking opportunity score: 96.58465387823186
# Minimum ranking opportunity score: 85.0

# %%
print("===== STALE CONTENT REASON CONSISTENCY =====")

stale_reason = refresh_queue[
    refresh_queue["refresh_reason"].str.contains(
        "content is stale",
        case=False,
        na=False
    )
]

print(
    "Pages claiming stale content:",
    len(stale_reason)
)

print(
    "Mean freshness score:",
    stale_reason["freshness_score"].mean()
)

print(
    "Maximum freshness score:",
    stale_reason["freshness_score"].max()
)

print("\nStale-content examples:")
print(
    stale_reason[
        [
            "content_id",
            "days_since_last_update",
            "freshness_score",
            "refresh_opportunity_score",
            "refresh_priority",
            "refresh_reason"
        ]
    ].head(10)
)
# Out:
# ===== STALE CONTENT REASON CONSISTENCY =====
# Pages claiming stale content: 37
# Mean freshness score: 70.5754141238012
# Maximum freshness score: 100.0
#
# Stale-content examples:
#                 content_id  days_since_last_update  freshness_score  \
# 53    content_02b0d6e30129                     313        83.870968
# 117   content_bbca724138f2                     236        63.172043
# 1703  content_cf56e2e2e282                     194        51.881720
# 2516  content_55a5b1c46474                     373       100.000000
# 2592  content_4f241bad48a3                     236        63.172043
# 5506  content_c2d929d83eaa                     193        51.612903
# 5608  content_94991fe6268c                     313        83.870968
# 5704  content_0a91db491d14                     193        51.612903
# 6256  content_f4b3081037b3                     231        61.827957
# 6641  content_40e140ba2934                     231        61.827957
#
#       refresh_opportunity_score refresh_priority  \
# 53                    71.256519         Critical
# 117                   69.163819             High
# 1703                  60.511627             High
# 2516                  58.965762           Medium
# 2592                  58.825403           Medium
# 5506                  55.015877           Medium
# 5608                  54.894815           Medium
# 5704                  54.776475           Medium
# 6256                  54.161032           Medium
# 6641                  53.776200           Medium
#
#                                          refresh_reason
# 53    strong ranking opportunity; significant perfor...
# 117   significant performance decline; content is stale
# 1703  significant performance decline; content is st...
# 2516  strong ranking opportunity; significant perfor...
# 2592  significant performance decline; content is stale
# 5506  significant performance decline; content is stale
# 5608  significant performance decline; content is stale
# 5704  significant performance decline; content is st...
# 6256  strong ranking opportunity; significant perfor...
# 6641       strong ranking opportunity; content is stale

# %%
print("===== FINAL FUTURE / LEAKAGE FIELD VALIDATION =====")

future_keywords = [
    "future",
    "next_",
    "next30",
    "next_30",
    "future_",
    "outcome",
    "target",
    "label",
    "conversion_future",
    "impressions_future",
    "clicks_future",
    "sessions_future"
]

queue_columns = refresh_queue.columns.tolist()

future_like_columns = []

for col in queue_columns:
    col_lower = col.lower()

    if any(keyword in col_lower for keyword in future_keywords):
        future_like_columns.append(col)

print("Future-like fields detected in ranked dataframe:")
print(future_like_columns)

if len(future_like_columns) == 0:
    print("\nPASS — no obvious future-window or target fields detected.")
else:
    print("\nWARNING — inspect these fields before finalizing.")
# Out:
# ===== FINAL FUTURE / LEAKAGE FIELD VALIDATION =====
# Future-like fields detected in ranked dataframe:
# []
#
# PASS — no obvious future-window or target fields detected.

# %%
print("\n===== SCORE INPUT FIELD CHECK =====")

score_components = [
    "demand_score",
    "visibility_score",
    "ranking_opportunity_score",
    "decline_score",
    "freshness_score"
]

print("Score component fields:")
for col in score_components:
    print("-", col)

print("\nUnderlying historical fields available:")
historical_fields = [
    "search_volume",
    "impressions_90d",
    "clicks_90d",
    "avg_position",
    "days_since_last_update",
    "impressions_last_30d",
    "impressions_prev_30d",
    "clicks_last_30d",
    "clicks_prev_30d"
]

for col in historical_fields:
    if col in refresh_queue.columns:
        print("✓", col)
    else:
        print("✗", col, "MISSING")
# Out:
# ===== SCORE INPUT FIELD CHECK =====
# Score component fields:
# - demand_score
# - visibility_score
# - ranking_opportunity_score
# - decline_score
# - freshness_score
#
# Underlying historical fields available:
# ✓ search_volume
# ✓ impressions_90d
# ✓ clicks_90d
# ✓ avg_position
# ✓ days_since_last_update
# ✓ impressions_last_30d
# ✓ impressions_prev_30d
# ✓ clicks_last_30d
# ✓ clicks_prev_30d

# %%
print("\n===== ID / DUPLICATE VALIDATION =====")

print(
    "Total rows:",
    len(refresh_queue)
)

print(
    "Unique content IDs:",
    refresh_queue["content_id"].nunique()
)

print(
    "Duplicate content IDs:",
    refresh_queue["content_id"].duplicated().sum()
)

if refresh_queue["content_id"].is_unique:
    print("\nPASS — every content_id appears exactly once.")
else:
    print("\nWARNING — duplicate content IDs detected.")
# Out:
# ===== ID / DUPLICATE VALIDATION =====
# Total rows: 27076
# Unique content IDs: 27076
# Duplicate content IDs: 0
#
# PASS — every content_id appears exactly once.

# %%
print("\n===== RANK INTEGRITY VALIDATION =====")

print("Minimum rank:", refresh_queue["refresh_rank"].min())
print("Maximum rank:", refresh_queue["refresh_rank"].max())
print("Unique ranks:", refresh_queue["refresh_rank"].nunique())

expected_ranks = set(range(1, len(refresh_queue) + 1))
actual_ranks = set(refresh_queue["refresh_rank"])

if actual_ranks == expected_ranks:
    print("\nPASS — refresh ranks are continuous from 1 to N.")
else:
    print("\nWARNING — rank gaps or duplicates detected.")
# Out:
# ===== RANK INTEGRITY VALIDATION =====
# Minimum rank: 1
# Maximum rank: 27076
# Unique ranks: 27076
#
# PASS — refresh ranks are continuous from 1 to N.

# %%
print("===== FINAL DATASET AUDIT =====")

print("Shape:", refresh_queue.shape)

print("\nMissing values:")
print(refresh_queue.isna().sum())

print("\nInfinite values:")
numeric_cols = refresh_queue.select_dtypes(include="number").columns
print(
    np.isinf(refresh_queue[numeric_cols]).sum()
)

print("\nDuplicate rows:", refresh_queue.duplicated().sum())

print("\nDuplicate content IDs:", refresh_queue["content_id"].duplicated().sum())

print("\nPriority missing:",
      refresh_queue["refresh_priority"].isna().sum())

print("\nAction missing:",
      refresh_queue["recommended_action"].isna().sum())

print("\nReason missing:",
      refresh_queue["refresh_reason"].isna().sum())

score_cols = [
    "demand_score",
    "visibility_score",
    "ranking_opportunity_score",
    "decline_score",
    "freshness_score",
    "refresh_opportunity_score"
]

print("\nScore range checks:")

for col in score_cols:
    print(
        col,
        "min =", refresh_queue[col].min(),
        "max =", refresh_queue[col].max(),
        "invalid =",
        ((refresh_queue[col] < 0) | (refresh_queue[col] > 100)).sum()
    )
# Out:
# ===== FINAL DATASET AUDIT =====
# Shape: (27076, 24)
#
# Missing values:
# refresh_rank                   0
# content_id                     0
# client_id                      0
# content_type                   0
# main_intent                  140
# search_volume                  0
# competition                    0
# impressions_90d                0
# clicks_90d                     0
# avg_position                   0
# days_since_last_update         0
# impressions_last_30d           0
# impressions_prev_30d           0
# clicks_last_30d                0
# clicks_prev_30d                0
# demand_score                   0
# visibility_score               0
# ranking_opportunity_score      0
# decline_score                  0
# freshness_score                0
# refresh_opportunity_score      0
# refresh_priority               0
# refresh_reason                 0
# recommended_action             0
# dtype: int64
#
# Infinite values:
# refresh_rank                 0
# search_volume                0
# competition                  0
# impressions_90d              0
# clicks_90d                   0
# avg_position                 0
# days_since_last_update       0
# impressions_last_30d         0
# impressions_prev_30d         0
# clicks_last_30d              0
# clicks_prev_30d              0
# demand_score                 0
# visibility_score             0
# ranking_opportunity_score    0
# decline_score                0
# freshness_score              0
# refresh_opportunity_score    0
# dtype: int64
#
# Duplicate rows: 0
#
# Duplicate content IDs: 0
#
# Priority missing: 0
#
# Action missing: 0
#
# Reason missing: 0
#
# Score range checks:
# demand_score min = 0.0 max = 100.0 invalid = 0
# visibility_score min = 5.268203896945729 max = 100.0 invalid = 0
# ranking_opportunity_score min = 20.0 max = 100.0 invalid = 0
# decline_score min = 0.0 max = 99.97458057956278 invalid = 0
# freshness_score min = 0.0 max = 100.0 invalid = 0
# refresh_opportunity_score min = 6.564393467561189 max = 78.83299237905797 invalid = 0

# %%
import os

print("Current working directory:")
print(os.getcwd())

print("\nCurrent directory contents:")
print(os.listdir("."))
# Out:
# Current working directory:
# /content/FlyRank-Internship
#
# Current directory contents:
# ['scripts', 'requirements.txt', 'data', 'GUIDE.md', 'work', '.github', 'AGENTS.md', 'high_priority_refresh_queue.csv', 'outputs', 'CLAUDE.md', 'refresh_priority_queue.csv', 'README.md', 'LICENSE', 'submission', '.git', '.gitignore', 'notebooks', 'DATA_USE.md', 'docs', 'SETUP.md', 'skills']

# %%
import os

print("Parent directory:")
print(os.listdir(".."))

print("\nTwo levels up:")
print(os.listdir("../.."))
# Out:
# Parent directory:
# ['.config', 'FlyRank-Internship', 'sample_data']
#
# Two levels up:
# ['var', 'proc', 'tmp', 'mnt', 'sbin', 'lib64', 'media', 'home', 'root', 'sys', 'opt', 'run', 'lib', 'lib32', 'dev', 'usr', 'libx32', 'boot', 'srv', 'etc', 'bin', 'kaggle', 'content', '.dockerenv', 'tools', 'datalab', 'python-apt', 'python-apt.tar.xz']

# %%
import os

print("Data folder:")
print(os.listdir("data"))

print("\nProcessed folder exists:",
      os.path.exists("data/processed"))
# Out:
# Data folder:
# ['raw']
#
# Processed folder exists: False

# %%
os.makedirs("data/processed", exist_ok=True)

print("Processed folder created:",
      os.path.exists("data/processed"))
# Out:
# Processed folder created: True

# %%
OUTPUT_PATH = "data/processed/content_refresh_ranked.csv"

refresh_queue.to_csv(
    OUTPUT_PATH,
    index=False
)

print("Saved successfully:", OUTPUT_PATH)
print("Rows:", len(refresh_queue))
print("Columns:", len(refresh_queue.columns))
# Out:
# Saved successfully: data/processed/content_refresh_ranked.csv
# Rows: 27076
# Columns: 24

# %%
import os

print("File exists:", os.path.exists(OUTPUT_PATH))

if os.path.exists(OUTPUT_PATH):
    print("File size:", os.path.getsize(OUTPUT_PATH), "bytes")
# Out:
# File exists: True
# File size: 6936240 bytes

# %%
# ===== CREATE CRITICAL REFRESH PAGES =====

critical_pages = refresh_queue[
    refresh_queue["refresh_priority"] == "Critical"
].copy()

CRITICAL_PATH = "data/processed/critical_refresh_pages.csv"

critical_pages.to_csv(
    CRITICAL_PATH,
    index=False
)

print("Critical pages:", len(critical_pages))
print("Saved to:", CRITICAL_PATH)
# Out:
# Critical pages: 86
# Saved to: data/processed/critical_refresh_pages.csv

# %%
import os

print("File exists:", os.path.exists(CRITICAL_PATH))

if os.path.exists(CRITICAL_PATH):
    print("File size:", os.path.getsize(CRITICAL_PATH), "bytes")
# Out:
# File exists: True
# File size: 26755 bytes

# %%
print("\nCritical file shape:", critical_pages.shape)

print("\nPriority distribution:")
print(critical_pages["refresh_priority"].value_counts())

print("\nTop 10 critical pages:")
display(
    critical_pages[
        [
            "refresh_rank",
            "content_id",
            "search_volume",
            "avg_position",
            "refresh_opportunity_score",
            "refresh_priority",
            "refresh_reason",
            "recommended_action"
        ]
    ].head(10)
)
# Out:
# Critical file shape: (86, 24)
#
# Priority distribution:
# refresh_priority
# Critical    86
# Name: count, dtype: int64
#
# Top 10 critical pages:
#    refresh_rank            content_id  search_volume  avg_position  \
# 0             1  content_8ba781dafa55         2900.0           9.0
# 1             2  content_e8fc703f7ef0         9900.0           9.5
# 2             3  content_d0a2a4e36acc         4400.0           7.6
# 3             4  content_c861e30f2f7a        22200.0           8.4
# 4             5  content_548f0bf562a9         9900.0           3.2
# 5             6  content_2725d2bcfac1         6600.0           9.1
# 6             7  content_2e0b3dc70916         9900.0           6.9
# 7             8  content_5fe46e04994d         1900.0           4.2
# 8             9  content_e6955a2c59dc         3600.0           7.1
# 9            10  content_2db251d1a841        14800.0           5.6
#
#    refresh_opportunity_score refresh_priority  \
# 0                  78.832992         Critical
# 1                  77.345593         Critical
# 2                  77.155243         Critical
# 3                  77.027080         Critical
# 4                  76.876566         Critical
# 5                  76.803039         Critical
# 6                  75.606698         Critical
# 7                  75.333024         Critical
# 8                  75.265070         Critical
# 9                  75.243454         Critical
#
#                                       refresh_reason   recommended_action
# 0  strong ranking opportunity; significant perfor...  Refresh immediately
# 1  strong ranking opportunity; significant perfor...  Refresh immediately
# 2  strong ranking opportunity; significant perfor...  Refresh immediately
# 3  strong ranking opportunity; significant perfor...  Refresh immediately
# 4  strong ranking opportunity; significant perfor...  Refresh immediately
# 5  strong ranking opportunity; high search demand...  Refresh immediately
# 6  strong ranking opportunity; high search demand...  Refresh immediately
# 7  strong ranking opportunity; strong existing vi...  Refresh immediately
# 8  strong ranking opportunity; high search demand...  Refresh immediately
# 9  strong ranking opportunity; high search demand...  Refresh immediately

# %%
# ============================================================
# STEP 6 — EXECUTIVE SUMMARY
# ============================================================

print("=" * 60)
print("REFRESH / CONTENT OPPORTUNITY SCORING — EXECUTIVE SUMMARY")
print("=" * 60)

total_pages = len(refresh_queue)

priority_counts = refresh_queue["refresh_priority"].value_counts()

print(f"\nTotal pages analyzed: {total_pages:,}")

print("\n----- PRIORITY DISTRIBUTION -----")

for priority in ["Critical", "High", "Medium", "Low"]:
    count = priority_counts.get(priority, 0)
    percentage = (count / total_pages) * 100

    print(
        f"{priority:<10} "
        f"{count:>6,} pages "
        f"({percentage:.2f}%)"
    )

print("\n----- SCORE SUMMARY -----")

score_cols = [
    "demand_score",
    "visibility_score",
    "ranking_opportunity_score",
    "decline_score",
    "freshness_score",
    "refresh_opportunity_score"
]

for col in score_cols:
    print(
        f"{col:<30} "
        f"mean = {refresh_queue[col].mean():.2f}"
    )

print("\n----- CRITICAL PAGE SUMMARY -----")

critical = refresh_queue[
    refresh_queue["refresh_priority"] == "Critical"
]

print("Critical pages:", len(critical))

print(
    "Average refresh opportunity:",
    f"{critical['refresh_opportunity_score'].mean():.2f}"
)

print(
    "Average demand score:",
    f"{critical['demand_score'].mean():.2f}"
)

print(
    "Average visibility score:",
    f"{critical['visibility_score'].mean():.2f}"
)

print(
    "Average ranking opportunity:",
    f"{critical['ranking_opportunity_score'].mean():.2f}"
)

print(
    "Average decline score:",
    f"{critical['decline_score'].mean():.2f}"
)

print(
    "Average position:",
    f"{critical['avg_position'].mean():.2f}"
)

print("\n----- VALIDATION STATUS -----")

print("Score ranges: PASS")
print("Priority monotonicity: PASS")
print("Priority/action consistency: PASS")
print("Reason consistency: PASS")
print("Future/leakage check: PASS")
print("Duplicate content IDs: PASS")
print("Rank integrity: PASS")
# Out:
# ============================================================
# REFRESH / CONTENT OPPORTUNITY SCORING — EXECUTIVE SUMMARY
# ============================================================
#
# Total pages analyzed: 27,076
#
# ----- PRIORITY DISTRIBUTION -----
# Critical       86 pages (0.32%)
# High        1,856 pages (6.85%)
# Medium     14,253 pages (52.64%)
# Low        10,881 pages (40.19%)
#
# ----- SCORE SUMMARY -----
# demand_score                   mean = 18.62
# visibility_score               mean = 49.98
# ranking_opportunity_score      mean = 74.44
# decline_score                  mean = 59.91
# freshness_score                mean = 12.50
# refresh_opportunity_score      mean = 46.49
#
# ----- CRITICAL PAGE SUMMARY -----
# Critical pages: 86
# Average refresh opportunity: 72.33
# Average demand score: 65.79
# Average visibility score: 69.68
# Average ranking opportunity: 97.21
# Average decline score: 79.96
# Average position: 7.35
#
# ----- VALIDATION STATUS -----
# Score ranges: PASS
# Priority monotonicity: PASS
# Priority/action consistency: PASS
# Reason consistency: PASS
# Future/leakage check: PASS
# Duplicate content IDs: PASS
# Rank integrity: PASS

# %%
import matplotlib.pyplot as plt

priority_order = ["Critical", "High", "Medium", "Low"]

priority_counts = (
    refresh_queue["refresh_priority"]
    .value_counts()
    .reindex(priority_order)
)

plt.figure(figsize=(8, 5))

plt.bar(
    priority_counts.index,
    priority_counts.values
)

plt.title("Content Pages by Refresh Priority")
plt.xlabel("Refresh Priority")
plt.ylabel("Number of Pages")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))

plt.hist(
    refresh_queue["refresh_opportunity_score"],
    bins=30
)

plt.title("Distribution of Refresh Opportunity Scores")
plt.xlabel("Refresh Opportunity Score")
plt.ylabel("Number of Pages")

plt.tight_layout()
plt.show()

# %%
critical = refresh_queue[
    refresh_queue["refresh_priority"] == "Critical"
]

components = [
    "demand_score",
    "visibility_score",
    "ranking_opportunity_score",
    "decline_score",
    "freshness_score"
]

means = critical[components].mean()

plt.figure(figsize=(10, 5))

plt.bar(
    components,
    means.values
)

plt.title("Average Score Components — Critical Pages")
plt.xlabel("Score Component")
plt.ylabel("Average Score")

plt.xticks(rotation=30)

plt.tight_layout()
plt.show()

# %%
import os

print("===== REPOSITORY STRUCTURE =====")

for root, dirs, files in os.walk("."):
    # Skip Git internals
    dirs[:] = [d for d in dirs if d != ".git"]

    level = root.count(os.sep)
    indent = "  " * level

    print(f"{indent}{os.path.basename(root)}/")

    for file in files[:20]:
        print(f"{indent}  {file}")
# Out:
# ===== REPOSITORY STRUCTURE =====
# ./
#   requirements.txt
#   GUIDE.md
#   AGENTS.md
#   high_priority_refresh_queue.csv
#   CLAUDE.md
#   refresh_priority_queue.csv
#   README.md
#   LICENSE
#   .gitignore
#   DATA_USE.md
#   SETUP.md
#   scripts/
#     02_baseline_score.py
#     01_prepare_features.py
#     ml_utils.py
#     04_evaluate_and_export.py
#     run_all.py
#     05_build_pdf_report.py
#     03_train_model.py
#   data/
#     processed/
#       critical_refresh_pages.csv
#       content_refresh_ranked.csv
#     raw/
#       content_refresh_anonymized.csv
#   work/
#     capstone_report_template.md
#     README.md
#     notebooks/
#       w03_feature_leakage_check.ipynb
#       w01_research_question.ipynb
#       w02_ml_task_framing.ipynb
#       capstone.ipynb
#       w03_data_contract.ipynb
#       w06_validation_audit.ipynb
#       w04_baseline_score.ipynb
#       w07_action_playbook.ipynb
#       w05_model.ipynb
#       w04_signal_audit.ipynb
#   .github/
#     workflows/
#       personalize.yml
#       data-path-smoke.yml
#       smoke-test.yml
#   outputs/
#     refresh_queue_sample.csv
#     model_report.md
#     charts/
#       trend_distribution.svg
#       top_feature_importance.svg
#       action_mix.svg
#       top_reason_codes.svg
#       confidence_mix.svg
#   submission/
#     README.md
#     paper_url.txt
#   notebooks/
#     02_your_first_readable_model.ipynb
#     03_working_with_the_full_release.ipynb
#     01_first_look_and_discovery.ipynb
#   docs/
#     data-dictionary.md
#     ml-core-foundation-framework.md
#     ml-intern-dataset-and-lane-guide.md
#     flyrank-seo-research-march-2026.pdf
#     intern-free-tooling-guide.md
#   skills/
#     README.md
#     hunting-leakage-and-validating/
#       SKILL.md
#     writing-research-papers/
#       SKILL.md
#     auditing-signals/
#       SKILL.md
#     querying-big-datasets/
#       SKILL.md
#     building-baselines/
#       SKILL.md
#     framing-ml-problems/
#       SKILL.md
#     writing-honest-claims/
#       SKILL.md
#     flyrank/
#       flyrank-context/
#         SKILL.md
#       flyrank-data/
#         SKILL.md
#     deploying-static-pages/
#       SKILL.md
#     directing-your-ai-assistant/
#       SKILL.md
#     training-honest-models/
#       SKILL.md
#     writing-data-contracts/
#       SKILL.md

# %% [markdown]
# # CTR / Engagement Opportunity Scoring for Search-Visible Content
#
# ## Capstone Research Paper Notebook
#
# This capstone identifies search-visible content pages with the strongest observed opportunities to improve click-through rate (CTR) and engagement relative to position-based expectations, and converts those opportunities into ranked, actionable recommendations.

# %% [markdown]
# ## 1. Question
#
# ### Research Question
#
# Which search-visible content pages show the strongest opportunities to improve click-through rate (CTR) and/or engagement relative to position-based expectations?
#
# ### Decision Supported
#
# The analysis supports prioritization of content pages for CTR improvement, content refresh, engagement improvement, or monitoring based on observed search performance and engagement gaps.
#
# This is a decision-support analysis. It does not claim that the recommended actions will cause ranking, traffic, CTR, or engagement improvements.

# %% [markdown]
# ## 2. Data
# ## Data Scope
#
# The analysis uses the FlyRank ML Internship warehouse release and
# focuses on search-visible content records with measurable search
# position and impressions.
#
# The released dataset contains 30,000 rows and 53 columns. All 30,000
# rows have valid search visibility and no missing canonical CTR or
# engagement metrics. Scroll-related fields contain 125 missing values.
#
# For opportunity scoring, rows are restricted to the 28,795 records with
# positive search position and positive impressions. The 1,205 records
# with zero average position are excluded from the ranking population
# because they do not provide a measurable search-position signal.
#
# No client names, domains, private queries, URLs, credentials, or raw
# exports are exposed in the analysis.

# %% [markdown]
# ## 3. Methodology
#
# # 3. Methodology
#
# The analysis focuses on search-visible content with measurable impressions and position.
#
# The scoring framework uses:
#
# - Expected CTR
# - Observed CTR
# - CTR gap
# - Expected engagement
# - Observed engagement where measurable
# - Engagement gap where measurable
# - Visibility weight
# - CTR opportunity intensity
# - Engagement opportunity intensity
# - Performance opportunity
# - Opportunity score
#
# CTR opportunity is based on the difference between observed CTR and the position-based expected CTR benchmark.
#
# Engagement opportunity is calculated only where engagement is measurable. Missing engagement is not interpreted as poor engagement.
#
# Visibility weight gives greater priority to opportunities with meaningful search exposure.
#
# The resulting opportunity score is bounded between 0 and 1 and is used to rank content for decision-support recommendations.
#
# The analysis does not use future-window outcome variables to construct the score.

# %%
# Use the existing scoring dataframe
scoring_df = scoring_df.copy()

print("Scoring dataframe shape:", scoring_df.shape)
print("Columns:", len(scoring_df.columns))
print("Missing opportunity scores:", scoring_df["opportunity_score"].isna().sum())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2432/2287527098.py in <cell line: 0>()
#       1 # Use the existing scoring dataframe
# ----> 2 scoring_df = scoring_df.copy()
#       3
#       4 print("Scoring dataframe shape:", scoring_df.shape)
#       5 print("Columns:", len(scoring_df.columns))
#
# NameError: name 'scoring_df' is not defined

# %% [markdown]
# ## 4. Results (vs baseline)
#
# *Model vs baseline on the same split. The honest table.*

# %% [markdown]
# ## 5. Limitations
#
# *What this work cannot claim.*

# %% [markdown]
# ## 6. Ranked recommendations
#
# *The action playbook output — the paper's recommendations section.*

# %% [markdown]
# ## 7. Artifacts the paper embeds
#
# *Generate/collect the charts and tables your deployed page will show.*

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
# - [ ] My deployed paper has **all 9 sections** — including the **Abstract** at the top and **Acknowledgments & data credit** (the https://flyrank.ai link) at the bottom.
# - [ ] **ML-12 done in this notebook's closing cells:** 5-minute demo outline + a social-post cut + a 3-sentence employer-facing summary.
